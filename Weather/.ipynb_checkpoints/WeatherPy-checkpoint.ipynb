# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from matplotlib.pyplot import subplots, show
from pprint import pprint
import json

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 643

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&units=metric&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]['lat']
        city_lng = city_weather["coord"]['lon']
        city_max_temp = city_weather["main"]['temp_max']
        city_humidity = city_weather["main"]['humidity']
        city_clouds = city_weather["clouds"]['all']
        city_wind = city_weather["wind"]['speed']
        city_country = city_weather["sys"]['country']
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | concordia
# Processing Record 2 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 3 of Set 1 | itacoatiara
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | alekseyevsk
# Processing Record 6 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 1 | waitati
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | madingou
# Processing Record 11 of Set 1 | ciparay
# Processing Record 12 of Set 1 | vangaindrano
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | leningradskiy
# Processing Record 15 of Set 1 | moose factory
# Processing Record 16 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | gojra
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | lasa
# Processing Record 21 of Set 1 | hasaki
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | tuktoyaktuk
# Processing Record 26 of Set 1 | kimberley
# Processing Record 27 of Set 1 | tari
# Processing Record 28 of Set 1 | tartagal
# Processing Record 29 of Set 1 | agadir
# Processing Record 30 of Set 1 | roald
# Processing Record 31 of Set 1 | san rafael
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | quepos
# Processing Record 35 of Set 1 | nishihara
# Processing Record 36 of Set 1 | astana
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | roblin
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | imbituba
# Processing Record 41 of Set 1 | san roque
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | nanortalik
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | sonoita
# Processing Record 46 of Set 1 | pala
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | margate
# Processing Record 0 of Set 2 | geraldton
# Processing Record 1 of Set 2 | makakilo city
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | kempsey
# Processing Record 4 of Set 2 | nelson bay
# Processing Record 5 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 6 of Set 2 | vanimo
# Processing Record 7 of Set 2 | kozluk
# Processing Record 8 of Set 2 | turukhansk
# Processing Record 9 of Set 2 | tambacounda
# Processing Record 10 of Set 2 | ribeira grande
# Processing Record 11 of Set 2 | amahai
# Processing Record 12 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | soyo
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | mar del plata
# Processing Record 21 of Set 2 | chicama
# Processing Record 22 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 2 | novo aripuana
# Processing Record 24 of Set 2 | oyama
# Processing Record 25 of Set 2 | koundara
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | magrath
# Processing Record 28 of Set 2 | san carlos de bariloche
# Processing Record 29 of Set 2 | laguna
# Processing Record 30 of Set 2 | port moresby
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | constitucion
# Processing Record 33 of Set 2 | pombas
# Processing Record 34 of Set 2 | kavaratti
# Processing Record 35 of Set 2 | mauriti
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | pacific grove
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | gizo
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 2 | yar-sale
# Processing Record 47 of Set 2 | san luis
# Processing Record 48 of Set 2 | bhatkal
# Processing Record 49 of Set 2 | grindavik
# Processing Record 0 of Set 3 | nalut
# Processing Record 1 of Set 3 | ashibetsu
# Processing Record 2 of Set 3 | ocampo
# Processing Record 3 of Set 3 | palmas
# Processing Record 4 of Set 3 | afanasyevo
# City not found. Skipping...
# Processing Record 5 of Set 3 | ulaanbaatar
# Processing Record 6 of Set 3 | noumea
# Processing Record 7 of Set 3 | yellowknife
# Processing Record 8 of Set 3 | namatanai
# Processing Record 9 of Set 3 | sainte-anne-des-monts
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | isangel
# Processing Record 12 of Set 3 | richards bay
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | xingcheng
# Processing Record 17 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 3 | busselton
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | pisco
# Processing Record 21 of Set 3 | maputo
# Processing Record 22 of Set 3 | dakar
# Processing Record 23 of Set 3 | marsh harbour
# Processing Record 24 of Set 3 | lewisporte
# Processing Record 25 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 3 | luganville
# Processing Record 27 of Set 3 | shalinskoye
# Processing Record 28 of Set 3 | port lincoln
# Processing Record 29 of Set 3 | skibbereen
# Processing Record 30 of Set 3 | yabrud
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | kloulklubed
# Processing Record 33 of Set 3 | yialos
# City not found. Skipping...
# Processing Record 34 of Set 3 | palmer
# Processing Record 35 of Set 3 | chara
# Processing Record 36 of Set 3 | taybad
# Processing Record 37 of Set 3 | acapulco
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | boguchany
# Processing Record 40 of Set 3 | pak thong chai
# Processing Record 41 of Set 3 | nha trang
# Processing Record 42 of Set 3 | the valley
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | bilma
# Processing Record 45 of Set 3 | vila franca do campo
# Processing Record 46 of Set 3 | havoysund
# Processing Record 47 of Set 3 | santa rosa
# Processing Record 48 of Set 3 | kudahuvadhoo
# Processing Record 49 of Set 3 | boundiali
# Processing Record 0 of Set 4 | narimanov
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | ilulissat
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | kasongo-lunda
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | vigrestad
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | yumen
# Processing Record 10 of Set 4 | umm durman
# City not found. Skipping...
# Processing Record 11 of Set 4 | hermanus
# Processing Record 12 of Set 4 | mae ramat
# Processing Record 13 of Set 4 | alexandria
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | kruisfontein
# Processing Record 17 of Set 4 | songea
# Processing Record 18 of Set 4 | yokadouma
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | mattru
# Processing Record 21 of Set 4 | guider
# Processing Record 22 of Set 4 | namibe
# Processing Record 23 of Set 4 | bhachau
# Processing Record 24 of Set 4 | shelburne
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | chuy
# Processing Record 29 of Set 4 | jardim
# Processing Record 30 of Set 4 | zhigansk
# Processing Record 31 of Set 4 | grand gaube
# Processing Record 32 of Set 4 | olavarria
# Processing Record 33 of Set 4 | lahat
# Processing Record 34 of Set 4 | mayo
# Processing Record 35 of Set 4 | strezhevoy
# Processing Record 36 of Set 4 | bridlington
# Processing Record 37 of Set 4 | lavrentiya
# Processing Record 38 of Set 4 | juneau
# Processing Record 39 of Set 4 | sao filipe
# Processing Record 40 of Set 4 | alice springs
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | jamestown
# Processing Record 43 of Set 4 | vardo
# Processing Record 44 of Set 4 | aanekoski
# Processing Record 45 of Set 4 | tongliao
# Processing Record 46 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 4 | amga
# Processing Record 48 of Set 4 | goundam
# Processing Record 49 of Set 4 | naqadeh
# Processing Record 0 of Set 5 | bethel
# Processing Record 1 of Set 5 | kirakira
# Processing Record 2 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 5 | esmeraldas
# Processing Record 4 of Set 5 | nantucket
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | naron
# Processing Record 7 of Set 5 | bosaso
# Processing Record 8 of Set 5 | fortuna
# Processing Record 9 of Set 5 | riyadh
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | ormara
# Processing Record 12 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 5 | jeremie
# Processing Record 14 of Set 5 | ahipara
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | general pico
# Processing Record 17 of Set 5 | almeirim
# Processing Record 18 of Set 5 | maneadero
# Processing Record 19 of Set 5 | norman wells
# Processing Record 20 of Set 5 | daru
# Processing Record 21 of Set 5 | faanui
# Processing Record 22 of Set 5 | puerto ayora
# Processing Record 23 of Set 5 | hatillo
# Processing Record 24 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 5 | kang
# Processing Record 27 of Set 5 | hanyang
# Processing Record 28 of Set 5 | polewali
# Processing Record 29 of Set 5 | novyy urgal
# Processing Record 30 of Set 5 | chokurdakh
# Processing Record 31 of Set 5 | temerloh
# Processing Record 32 of Set 5 | tilichiki
# Processing Record 33 of Set 5 | buzdyak
# Processing Record 34 of Set 5 | rio claro
# Processing Record 35 of Set 5 | kalmunai
# Processing Record 36 of Set 5 | takaka
# Processing Record 37 of Set 5 | guiren
# Processing Record 38 of Set 5 | sibolga
# Processing Record 39 of Set 5 | waingapu
# Processing Record 40 of Set 5 | bathsheba
# Processing Record 41 of Set 5 | bazaliya
# Processing Record 42 of Set 5 | port hardy
# Processing Record 43 of Set 5 | khatanga
# Processing Record 44 of Set 5 | basoko
# Processing Record 45 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 5 | atuona
# Processing Record 47 of Set 5 | matara
# Processing Record 48 of Set 5 | atambua
# Processing Record 49 of Set 5 | yei
# Processing Record 0 of Set 6 | sao gabriel da cachoeira
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | port blair
# Processing Record 3 of Set 6 | bay roberts
# Processing Record 4 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 6 | vostok
# Processing Record 6 of Set 6 | bengkulu
# Processing Record 7 of Set 6 | klaksvik
# Processing Record 8 of Set 6 | sorland
# Processing Record 9 of Set 6 | vila velha
# Processing Record 10 of Set 6 | pedasi
# Processing Record 11 of Set 6 | prince rupert
# Processing Record 12 of Set 6 | simao
# Processing Record 13 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 6 | paucartambo
# City not found. Skipping...
# Processing Record 15 of Set 6 | mildura
# Processing Record 16 of Set 6 | xining
# Processing Record 17 of Set 6 | bacolod
# Processing Record 18 of Set 6 | lokosovo
# Processing Record 19 of Set 6 | rosarito
# Processing Record 20 of Set 6 | turayf
# Processing Record 21 of Set 6 | meulaboh
# Processing Record 22 of Set 6 | walvis bay
# Processing Record 23 of Set 6 | jalu
# Processing Record 24 of Set 6 | qaanaaq
# Processing Record 25 of Set 6 | plouzane
# Processing Record 26 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 27 of Set 6 | pochutla
# Processing Record 28 of Set 6 | mubende
# Processing Record 29 of Set 6 | biryusinsk
# Processing Record 30 of Set 6 | sile
# Processing Record 31 of Set 6 | esperance
# Processing Record 32 of Set 6 | santa fe
# Processing Record 33 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 6 | labytnangi
# Processing Record 35 of Set 6 | monrovia
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | college
# Processing Record 38 of Set 6 | matagami
# Processing Record 39 of Set 6 | ugoofaaru
# Processing Record 40 of Set 6 | gazli
# Processing Record 41 of Set 6 | abha
# Processing Record 42 of Set 6 | victoria
# Processing Record 43 of Set 6 | brae
# Processing Record 44 of Set 6 | lorengau
# Processing Record 45 of Set 6 | arman
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | oranjemund
# Processing Record 48 of Set 6 | nemuro
# Processing Record 49 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 0 of Set 7 | yuxia
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | mabaruma
# Processing Record 3 of Set 7 | beloha
# Processing Record 4 of Set 7 | velsk
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | tura
# Processing Record 7 of Set 7 | dunedin
# Processing Record 8 of Set 7 | katsuura
# Processing Record 9 of Set 7 | mount isa
# Processing Record 10 of Set 7 | bonavista
# Processing Record 11 of Set 7 | lazaro cardenas
# Processing Record 12 of Set 7 | rodrigues alves
# Processing Record 13 of Set 7 | chulym
# Processing Record 14 of Set 7 | havre
# Processing Record 15 of Set 7 | hithadhoo
# Processing Record 16 of Set 7 | ixtapa
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 7 | saint-pierre
# Processing Record 20 of Set 7 | nueva italia
# Processing Record 21 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 7 | talnakh
# Processing Record 23 of Set 7 | andenes
# Processing Record 24 of Set 7 | pavlohrad
# Processing Record 25 of Set 7 | thompson
# Processing Record 26 of Set 7 | karagaylinskiy
# Processing Record 27 of Set 7 | fallon
# Processing Record 28 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 7 | rjukan
# Processing Record 30 of Set 7 | tarko-sale
# Processing Record 31 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 7 | hospet
# Processing Record 33 of Set 7 | mozarlandia
# Processing Record 34 of Set 7 | umm kaddadah
# Processing Record 35 of Set 7 | chak azam sahu
# Processing Record 36 of Set 7 | berlevag
# Processing Record 37 of Set 7 | aykhal
# Processing Record 38 of Set 7 | abu samrah
# Processing Record 39 of Set 7 | jiaozuo
# Processing Record 40 of Set 7 | lesosibirsk
# Processing Record 41 of Set 7 | pevek
# Processing Record 42 of Set 7 | cartagena
# Processing Record 43 of Set 7 | karratha
# Processing Record 44 of Set 7 | jambi
# Processing Record 45 of Set 7 | luderitz
# Processing Record 46 of Set 7 | yagodnoye
# Processing Record 47 of Set 7 | vao
# Processing Record 48 of Set 7 | tautira
# Processing Record 49 of Set 7 | mombaca
# Processing Record 0 of Set 8 | remuna
# Processing Record 1 of Set 8 | comodoro rivadavia
# Processing Record 2 of Set 8 | matay
# Processing Record 3 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 8 | srednekolymsk
# Processing Record 5 of Set 8 | opuwo
# Processing Record 6 of Set 8 | brooks
# Processing Record 7 of Set 8 | makaha
# Processing Record 8 of Set 8 | hofn
# Processing Record 9 of Set 8 | marathon
# Processing Record 10 of Set 8 | san jose
# Processing Record 11 of Set 8 | yate
# Processing Record 12 of Set 8 | mogadishu
# Processing Record 13 of Set 8 | kwakoa
# Processing Record 14 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 8 | necochea
# Processing Record 16 of Set 8 | taraz
# Processing Record 17 of Set 8 | himora
# City not found. Skipping...
# Processing Record 18 of Set 8 | te anau
# Processing Record 19 of Set 8 | antofagasta
# Processing Record 20 of Set 8 | gurupa
# Processing Record 21 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 22 of Set 8 | dzilam gonzalez
# Processing Record 23 of Set 8 | porto velho
# Processing Record 24 of Set 8 | amos
# Processing Record 25 of Set 8 | qasigiannguit
# Processing Record 26 of Set 8 | sungurlu
# Processing Record 27 of Set 8 | buraydah
# Processing Record 28 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 8 | rio grande
# Processing Record 30 of Set 8 | bereznik
# Processing Record 31 of Set 8 | henties bay
# Processing Record 32 of Set 8 | udachnyy
# Processing Record 33 of Set 8 | naze
# Processing Record 34 of Set 8 | marzuq
# Processing Record 35 of Set 8 | diamantino
# Processing Record 36 of Set 8 | tessalit
# Processing Record 37 of Set 8 | bjerringbro
# Processing Record 38 of Set 8 | dalinghe
# City not found. Skipping...
# Processing Record 39 of Set 8 | codajas
# Processing Record 40 of Set 8 | wlodawa
# Processing Record 41 of Set 8 | talcahuano
# Processing Record 42 of Set 8 | verkhnevilyuysk
# Processing Record 43 of Set 8 | chapais
# Processing Record 44 of Set 8 | sukumo
# Processing Record 45 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 8 | colac
# Processing Record 47 of Set 8 | shache
# Processing Record 48 of Set 8 | greenville
# Processing Record 49 of Set 8 | wahpeton
# Processing Record 0 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 1 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 9 | touros
# Processing Record 3 of Set 9 | cidreira
# Processing Record 4 of Set 9 | rocha
# Processing Record 5 of Set 9 | kinwat
# Processing Record 6 of Set 9 | porto novo
# Processing Record 7 of Set 9 | saint-paul
# Processing Record 8 of Set 9 | korla
# Processing Record 9 of Set 9 | rorvik
# Processing Record 10 of Set 9 | jibuti
# Processing Record 11 of Set 9 | malumfashi
# Processing Record 12 of Set 9 | visby
# Processing Record 13 of Set 9 | lakes entrance
# Processing Record 14 of Set 9 | kupino
# Processing Record 15 of Set 9 | kushima
# Processing Record 16 of Set 9 | airai
# Processing Record 17 of Set 9 | ardahan
# Processing Record 18 of Set 9 | buala
# Processing Record 19 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 9 | ahuimanu
# Processing Record 21 of Set 9 | broome
# Processing Record 22 of Set 9 | saulkrasti
# Processing Record 23 of Set 9 | belyy yar
# Processing Record 24 of Set 9 | po
# City not found. Skipping...
# Processing Record 25 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 26 of Set 9 | homa bay
# Processing Record 27 of Set 9 | ambon
# Processing Record 28 of Set 9 | mapiripan
# Processing Record 29 of Set 9 | kangaatsiaq
# Processing Record 30 of Set 9 | siilinjarvi
# Processing Record 31 of Set 9 | port-cartier
# Processing Record 32 of Set 9 | swellendam
# Processing Record 33 of Set 9 | ucluelet
# Processing Record 34 of Set 9 | zhuhai
# Processing Record 35 of Set 9 | sorbhog
# Processing Record 36 of Set 9 | saint-augustin
# Processing Record 37 of Set 9 | ponta do sol
# Processing Record 38 of Set 9 | bilibino
# Processing Record 39 of Set 9 | maraa
# Processing Record 40 of Set 9 | qaqortoq
# Processing Record 41 of Set 9 | san policarpo
# Processing Record 42 of Set 9 | taonan
# Processing Record 43 of Set 9 | bedele
# Processing Record 44 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 45 of Set 9 | atar
# Processing Record 46 of Set 9 | burnie
# Processing Record 47 of Set 9 | dwarka
# Processing Record 48 of Set 9 | saldanha
# Processing Record 49 of Set 9 | mazyr
# Processing Record 0 of Set 10 | karlstad
# Processing Record 1 of Set 10 | kroya
# Processing Record 2 of Set 10 | sitka
# Processing Record 3 of Set 10 | paamiut
# Processing Record 4 of Set 10 | puerto baquerizo moreno
# Processing Record 5 of Set 10 | beringovskiy
# Processing Record 6 of Set 10 | sabinas
# Processing Record 7 of Set 10 | tambilil
# Processing Record 8 of Set 10 | dongying
# Processing Record 9 of Set 10 | culaman
# Processing Record 10 of Set 10 | kasongo
# Processing Record 11 of Set 10 | palu
# Processing Record 12 of Set 10 | san quintin
# Processing Record 13 of Set 10 | mnogovershinnyy
# Processing Record 14 of Set 10 | karoi
# Processing Record 15 of Set 10 | casian
# Processing Record 16 of Set 10 | penjamillo
# City not found. Skipping...
# Processing Record 17 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 18 of Set 10 | panama city
# Processing Record 19 of Set 10 | gazanjyk
# Processing Record 20 of Set 10 | brownwood
# Processing Record 21 of Set 10 | baykit
# Processing Record 22 of Set 10 | kamloops
# Processing Record 23 of Set 10 | polson
# Processing Record 24 of Set 10 | port macquarie
# Processing Record 25 of Set 10 | kokstad
# Processing Record 26 of Set 10 | krasnooktyabrskiy
# Processing Record 27 of Set 10 | ugra
# Processing Record 28 of Set 10 | kahului
# Processing Record 29 of Set 10 | codrington
# Processing Record 30 of Set 10 | parintins
# Processing Record 31 of Set 10 | springbok
# Processing Record 32 of Set 10 | ponta delgada
# Processing Record 33 of Set 10 | taltal
# Processing Record 34 of Set 10 | leh
# Processing Record 35 of Set 10 | novoagansk
# Processing Record 36 of Set 10 | zasova
# Processing Record 37 of Set 10 | williams lake
# Processing Record 38 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 10 | awbari
# Processing Record 40 of Set 10 | pilar
# Processing Record 41 of Set 10 | malinovoye ozero
# Processing Record 42 of Set 10 | puerto colombia
# Processing Record 43 of Set 10 | brantford
# Processing Record 44 of Set 10 | mongo
# Processing Record 45 of Set 10 | salalah
# Processing Record 46 of Set 10 | samarai
# Processing Record 47 of Set 10 | ibra
# Processing Record 48 of Set 10 | banda aceh
# Processing Record 49 of Set 10 | anadyr
# Processing Record 0 of Set 11 | olafsvik
# Processing Record 1 of Set 11 | waddan
# Processing Record 2 of Set 11 | ancud
# Processing Record 3 of Set 11 | lumphat
# Processing Record 4 of Set 11 | whitehorse
# Processing Record 5 of Set 11 | faya
# Processing Record 6 of Set 11 | alihe
# Processing Record 7 of Set 11 | haines junction
# Processing Record 8 of Set 11 | kikwit
# Processing Record 9 of Set 11 | nautla
# Processing Record 10 of Set 11 | nueve de julio
# Processing Record 11 of Set 11 | pazardzik
# City not found. Skipping...
# Processing Record 12 of Set 11 | hobyo
# Processing Record 13 of Set 11 | hambantota
# Processing Record 14 of Set 11 | broken hill
# Processing Record 15 of Set 11 | hami
# Processing Record 16 of Set 11 | sept-iles
# Processing Record 17 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 11 | appleton
# Processing Record 19 of Set 11 | chumikan
# Processing Record 20 of Set 11 | novikovo
# Processing Record 21 of Set 11 | acarigua
# Processing Record 22 of Set 11 | formosa
# Processing Record 23 of Set 11 | vestmanna
# Processing Record 24 of Set 11 | naantali
# Processing Record 25 of Set 11 | kilosa
# Processing Record 26 of Set 11 | marystown
# Processing Record 27 of Set 11 | jining
# Processing Record 28 of Set 11 | maturin
# Processing Record 29 of Set 11 | alofi
# Processing Record 30 of Set 11 | tekeli
# Processing Record 31 of Set 11 | dicabisagan
# Processing Record 32 of Set 11 | bubaque
# Processing Record 33 of Set 11 | kemijarvi
# Processing Record 34 of Set 11 | pointe-noire
# Processing Record 35 of Set 11 | harper
# Processing Record 36 of Set 11 | olga
# Processing Record 37 of Set 11 | tiznit
# Processing Record 38 of Set 11 | mbandaka
# Processing Record 39 of Set 11 | northam
# Processing Record 40 of Set 11 | ekhabi
# Processing Record 41 of Set 11 | bagnols-sur-ceze
# Processing Record 42 of Set 11 | belaya gora
# Processing Record 43 of Set 11 | suez
# Processing Record 44 of Set 11 | sovetskiy
# Processing Record 45 of Set 11 | rawlins
# Processing Record 46 of Set 11 | krasnoselkup
# Processing Record 47 of Set 11 | bairiki
# Processing Record 48 of Set 11 | north bend
# Processing Record 49 of Set 11 | komsomolskiy
# Processing Record 0 of Set 12 | port hedland
# Processing Record 1 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 12 | sao jose da coroa grande
# Processing Record 3 of Set 12 | hokitika
# Processing Record 4 of Set 12 | cubuk
# Processing Record 5 of Set 12 | lixourion
# Processing Record 6 of Set 12 | lata
# Processing Record 7 of Set 12 | maltahohe
# Processing Record 8 of Set 12 | port arthur
# Processing Record 9 of Set 12 | coihaique
# Processing Record 10 of Set 12 | matongo
# Processing Record 11 of Set 12 | anito
# Processing Record 12 of Set 12 | le port
# Processing Record 13 of Set 12 | biak
# Processing Record 14 of Set 12 | kaabong
# Processing Record 15 of Set 12 | saint-joseph
# Processing Record 16 of Set 12 | portel
# Processing Record 17 of Set 12 | sainte-adele
# Processing Record 18 of Set 12 | harker heights
# Processing Record 19 of Set 12 | wau
# Processing Record 20 of Set 12 | avera
# Processing Record 21 of Set 12 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 12 | fukue
# Processing Record 23 of Set 12 | dingle
# Processing Record 24 of Set 12 | uvinza
# Processing Record 25 of Set 12 | ieper
# Processing Record 26 of Set 12 | batman
# Processing Record 27 of Set 12 | abong mbang
# Processing Record 28 of Set 12 | kazanskoye
# Processing Record 29 of Set 12 | lujan
# Processing Record 30 of Set 12 | cumberland
# Processing Record 31 of Set 12 | ambilobe
# Processing Record 32 of Set 12 | flinders
# Processing Record 33 of Set 12 | karachi
# Processing Record 34 of Set 12 | havre-saint-pierre
# Processing Record 35 of Set 12 | abilene
# Processing Record 36 of Set 12 | port-gentil
# Processing Record 37 of Set 12 | puri
# Processing Record 38 of Set 12 | liverpool
# Processing Record 39 of Set 12 | itoigawa
# Processing Record 40 of Set 12 | vila do maio
# Processing Record 41 of Set 12 | kropotkin
# Processing Record 42 of Set 12 | port shepstone
# Processing Record 43 of Set 12 | antalaha
# Processing Record 44 of Set 12 | loiza
# Processing Record 45 of Set 12 | pavlodar
# Processing Record 46 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 47 of Set 12 | auki
# Processing Record 48 of Set 12 | huarmey
# Processing Record 49 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 0 of Set 13 | caravelas
# Processing Record 1 of Set 13 | kaniama
# Processing Record 2 of Set 13 | itapolis
# Processing Record 3 of Set 13 | xiongyue
# Processing Record 4 of Set 13 | luhyny
# Processing Record 5 of Set 13 | anloga
# Processing Record 6 of Set 13 | seoul
# Processing Record 7 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 13 | verkhnyaya inta
# Processing Record 9 of Set 13 | angola
# Processing Record 10 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 11 of Set 13 | poum
# Processing Record 12 of Set 13 | hovd
# Processing Record 13 of Set 13 | zhoucheng
# Processing Record 14 of Set 13 | mfou
# Processing Record 15 of Set 13 | taksimo
# Processing Record 16 of Set 13 | road town
# Processing Record 17 of Set 13 | moerai
# Processing Record 18 of Set 13 | aitape
# Processing Record 19 of Set 13 | jaffna
# Processing Record 20 of Set 13 | kuryk
# Processing Record 21 of Set 13 | oistins
# Processing Record 22 of Set 13 | ribeira brava
# Processing Record 23 of Set 13 | casablanca
# Processing Record 24 of Set 13 | okhotsk
# Processing Record 25 of Set 13 | el estor
# Processing Record 26 of Set 13 | mazatlan
# Processing Record 27 of Set 13 | kingaroy
# Processing Record 28 of Set 13 | tual
# Processing Record 29 of Set 13 | pandamatenga
# Processing Record 30 of Set 13 | puerto del rosario
# Processing Record 31 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 13 | barabinsk
# Processing Record 33 of Set 13 | muros
# Processing Record 34 of Set 13 | daloa
# Processing Record 35 of Set 13 | nayudupeta
# Processing Record 36 of Set 13 | pedara
# Processing Record 37 of Set 13 | kutum
# Processing Record 38 of Set 13 | coquimbo
# Processing Record 39 of Set 13 | xuanwu
# Processing Record 40 of Set 13 | plettenberg bay
# Processing Record 41 of Set 13 | kizema
# Processing Record 42 of Set 13 | sulangan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          585
# Lat           585
# Lng           585
# Max Temp      585
# Humidity      585
# Cloudiness    585
# Wind Speed    585
# Country       585
# Date          585
# dtype: int64

# %%
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    concordia -31.3930  -58.0209     22.73        41           0        3.75
# 1  itacoatiara  -3.1431  -58.4442     22.78        90          87        1.02
# 2   bredasdorp -34.5322   20.0403     13.39        75          73        1.14
# 3  alekseyevsk  57.8406  108.3492    -11.25        94         100        4.89
# 4      waitati -45.7500  170.5667     11.56        70          97        3.94
#
#   Country        Date
# 0      AR  1670300125
# 1      BR  1670300125
# 2      ZA  1670300126
# 3      RU  1670300127
# 4      NZ  1670300128

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          concordia -31.3930  -58.0209     22.73        41           0
# 1        itacoatiara  -3.1431  -58.4442     22.78        90          87
# 2         bredasdorp -34.5322   20.0403     13.39        75          73
# 3        alekseyevsk  57.8406  108.3492    -11.25        94         100
# 4            waitati -45.7500  170.5667     11.56        70          97
#
#          Wind Speed Country        Date
# City_ID
# 0              3.75      AR  1670300125
# 1              1.02      BR  1670300125
# 2              1.14      ZA  1670300126
# 3              4.89      RU  1670300127
# 4              3.94      NZ  1670300128

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x = city_data_df['Lat']
y=city_data_df['Max Temp']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Temperature in F')
plt.title('Max Temp vs. Latitude')
plt.grid(axis = 'both')
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x = city_data_df['Lat']
y=city_data_df['Humidity']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('Humidity vs. City Latitude')
plt.grid(axis = 'both')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x = city_data_df['Lat']
y=city_data_df['Cloudiness']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.title('Cloudiness vs. City Latitude')
plt.grid(axis = 'both')


# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x = city_data_df['Lat']
y=city_data_df['Wind Speed']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Wind Speed vs. City Latitude')
plt.grid(axis = 'both')
# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def func_regression(x,y,df,n,coor):
    headers = list(df.columns)
    x = df[headers[1]]
    y=df[headers[n]]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    correlation = st.pearsonr(x,y)
    print(f"The correlation between {headers[n]} and Latitude is {round(correlation[0],2)}")
    plt.xlabel('Latitude')
    plt.ylabel(headers[n]) 
    plt.annotate(line_eq,coor,color='red')
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df[('Lat')]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3          alekseyevsk  57.8406  108.3492    -11.25        94         100
# 9                kapaa  22.0752 -159.3190     24.18        91         100
# 10       leningradskiy  69.3833  178.4167    -21.88        88          90
# 11       moose factory  51.2585  -80.6094    -20.01        77         100
# 13               gojra  31.1487   72.6866     18.84        25           0
#
#          Wind Speed Country        Date
# City_ID
# 3              4.89      RU  1670300127
# 9              4.63      US  1670299974
# 10             2.47      RU  1670300131
# 11             4.63      CA  1670300012
# 13             1.69      PK  1670300132

# %%
list(northern_hemi_df.columns)
# Out:
# ['City',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Country',
#  'Date']

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df[('Lat')]<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          concordia -31.3930  -58.0209     22.73        41           0
# 1        itacoatiara  -3.1431  -58.4442     22.78        90          87
# 2         bredasdorp -34.5322   20.0403     13.39        75          73
# 4            waitati -45.7500  170.5667     11.56        70          97
# 5        east london -33.0153   27.9116     15.79        76          73
#
#          Wind Speed Country        Date
# City_ID
# 0              3.75      AR  1670300125
# 1              1.02      BR  1670300125
# 2              1.14      ZA  1670300126
# 4              3.94      NZ  1670300128
# 5              3.52      ZA  1670300128

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
func_regression(x,y,northern_hemi_df,3,(0,0))
# Out:
# The correlation between Max Temp and Latitude is -0.85

# %%
# Linear regression on Southern Hemisphere
func_regression(x,y,southern_hemi_df,3,(-55,20))
# Out:
# The correlation between Max Temp and Latitude is 0.53

# %% [markdown]
# ##### **Discussion about the linear relationship:**
#
# -The two plots depoict a linear relationship, although not exact, as all the points are not on the line.
# -The correlation of 0.53 for southern hemishphere further explains that relationship is not a perfect linear relationship and there are other factors impacting temperature, however, a large part of the change in temperature is still being driven by changes in latitude.
# -The correlation of -0.83 for northern hemishphere also explains that relationship is not a perfect linear relationship and there are other factors impacting temperature, however, a larger part of the change in temperature is being driven by changes in latitude in this case, as correlation is nearer to -1, which also confirms that the nature of relationship is inverse, i.e. as latitude increases, temperature decreases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
func_regression(x,y,northern_hemi_df,4,(0,58))
# Out:
# The correlation between Humidity and Latitude is 0.28

# %%
# Southern Hemisphere
func_regression(x,y,southern_hemi_df,4,(-56,47))
# Out:
# The correlation between Humidity and Latitude is 0.34

# %% [markdown]
# ## **Discussion about the linear relationship:**
# -The two plots depict a non-linear relationship, although majority of cities sre converging towrads the linear relationship, but very few cities fall on the line itself.
# -The correlation of 0.28 and 0.34 for both northern and southern hemishphere point to the fact that the trend line does not indicate a perfect linear relationship and there are other factors impacting humidity. Concluding that only a small part of the change in humidity is being driven by changes in latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
func_regression(x,y,northern_hemi_df,5,(58,63))
# Out:
# The correlation between Cloudiness and Latitude is 0.27

# %%
# Southern Hemisphere
func_regression(x,y,southern_hemi_df,5,(-55,40))
# Out:
# The correlation between Cloudiness and Latitude is 0.41

# %% [markdown]
# **Discussion about the linear relationship:**
# -The two plots depoict a non-linear relationship, as most of the points are not falling on the line.
# -The correlation is weak at 0.27 and 0.41 for the two hemishpheres, which further explains that relationship is weak and there are other missing factors impacting cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
func_regression(x,y,northern_hemi_df,6,(70,3.5))
# Out:
# The correlation between Wind Speed and Latitude is 0.22

# %%
# Southern Hemisphere
func_regression(x,y,southern_hemi_df,6,(-57,5.2))
# Out:
# The correlation between Wind Speed and Latitude is -0.32

# %% [markdown]
# **Discussion about the linear relationship:**
# -The two plots depoict that for most cities wind speed is in the similar range of =<6m/s.
# -The correlation is also weak at 0.22 and -0.32 for northern and southern hemishpheres respectively. Further, it is a weak inverse r4elationship for southern hemishphere.
# -There are clearly other factors as latitude is not the major driver of wind speed for a particular city.
