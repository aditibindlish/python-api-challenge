# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from matplotlib.pyplot import subplots, show
from pprint import pprint
import json

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
cities
# Out:
# Number of cities in the list: 616
# ['bredasdorp',
#  'ostrovnoy',
#  'talnakh',
#  'codrington',
#  'ushuaia',
#  'saint george',
#  'belushya guba',
#  'kouqian',
#  'busselton',
#  'khatanga',
#  'kars',
#  'kapaa',
#  'lompoc',
#  'luderitz',
#  'chokurdakh',
#  'wyndham',
#  'airai',
#  'nyuksenitsa',
#  'vaini',
#  'cape town',
#  'karpathos',
#  'jamestown',
#  'preobrazheniye',
#  'margate',
#  'atuona',
#  'esperance',
#  'diphu',
#  'almaznyy',
#  'georgetown',
#  'punta arenas',
#  'mataura',
#  'rikitea',
#  'pareora',
#  'dadu',
#  'beringovskiy',
#  'xai-xai',
#  'fougeres',
#  'barentsburg',
#  'sorland',
#  'bonavista',
#  'mar del plata',
#  'hobart',
#  'east london',
#  'trinidad',
#  'ingham',
#  'fergus falls',
#  'attawapiskat',
#  'hermanus',
#  'tuktoyaktuk',
#  'puerto ayora',
#  'guiglo',
#  'bassar',
#  'fortuna',
#  'saint-philippe',
#  'mnogovershinnyy',
#  'alice springs',
#  'severo-kurilsk',
#  'albany',
#  'colon',
#  'porto velho',
#  'new norfolk',
#  'coihaique',
#  'ribeira grande',
#  'illoqqortoormiut',
#  'provideniya',
#  'angangxi',
#  'butaritari',
#  'kottagudem',
#  'sentyabrskiy',
#  'kirakira',
#  'liverpool',
#  'saskylakh',
#  'karamay',
#  'adrar',
#  'tenango',
#  'sorvag',
#  'samarai',
#  'ullapool',
#  'tura',
#  'pangai',
#  'puro',
#  'boffa',
#  'sharjah',
#  'dikson',
#  'thompson',
#  'marzuq',
#  'tasiilaq',
#  'lavrentiya',
#  'araouane',
#  'hilo',
#  'castro',
#  'chuy',
#  'hithadhoo',
#  'norman wells',
#  'avarua',
#  'cidreira',
#  'tiksi',
#  'aklavik',
#  'jahangirpur',
#  'sambava',
#  'souillac',
#  'srednekolymsk',
#  'surt',
#  'rio gallegos',
#  'avera',
#  'vila velha',
#  'mys shmidta',
#  'yerbogachen',
#  'barrow',
#  'ketchikan',
#  'keshod',
#  'selma',
#  'cayenne',
#  'biu',
#  'harper',
#  'muravlenko',
#  'carnarvon',
#  'broken hill',
#  'noumea',
#  'achisay',
#  'manado',
#  'saint johnsbury',
#  'northam',
#  'grindavik',
#  'linfen',
#  'formosa do rio preto',
#  'upernavik',
#  'superior',
#  'bluff',
#  'kamenka',
#  'palabuhanratu',
#  'pacific grove',
#  'moyale',
#  'meulaboh',
#  'puerto escondido',
#  'ucluelet',
#  'heinola',
#  'hervey bay',
#  'yeppoon',
#  'acajutla',
#  'olinala',
#  'lebu',
#  'saint-joseph',
#  'show low',
#  'chara',
#  'ancud',
#  'rusape',
#  'coquimbo',
#  'qaanaaq',
#  'sassandra',
#  'sechura',
#  'toora-khem',
#  'cherskiy',
#  'lanxi',
#  'miranorte',
#  'jardim',
#  'traralgon',
#  'bubaque',
#  'yingshang',
#  'mildura',
#  'svetlyy',
#  'arraial do cabo',
#  'pangnirtung',
#  'port alfred',
#  'hasaki',
#  'aracuai',
#  'atbasar',
#  'marabba',
#  'shahr-e babak',
#  'wawa',
#  'laguna',
#  'torbay',
#  'udachnyy',
#  'yellowknife',
#  'iqaluit',
#  'longyearbyen',
#  'nanortalik',
#  'laukaa',
#  'barawe',
#  'weyburn',
#  'reconquista',
#  'ilulissat',
#  'devils lake',
#  'gorontalo',
#  'lahij',
#  'saint anthony',
#  'nizhneyansk',
#  'quatre cocos',
#  'klaksvik',
#  'burica',
#  'cedar lake',
#  'vanavara',
#  'faanui',
#  'medyn',
#  'pisco',
#  'chojnice',
#  'guapiacu',
#  'susanville',
#  'coahuayana',
#  'alofi',
#  'buraydah',
#  'mansehra',
#  'saleaula',
#  'samusu',
#  'ponta do sol',
#  'makinsk',
#  'bambous virieux',
#  'bengkulu',
#  'knysna',
#  'saldanha',
#  'mahebourg',
#  'san francisco',
#  'eureka',
#  'port lincoln',
#  'bogorodskoye',
#  'nagas',
#  'sur',
#  'husavik',
#  'portland',
#  'solvychegodsk',
#  'vangaindrano',
#  'tsihombe',
#  'qostanay',
#  'sao joao da barra',
#  'baghdad',
#  'itarema',
#  'kosh-agach',
#  'parana',
#  'hailun',
#  'nikolskoye',
#  'san quintin',
#  'phan rang',
#  'hanna',
#  'cabo san lucas',
#  'taolanaro',
#  'fort smith',
#  'novyy urengoy',
#  'iquique',
#  'qasigiannguit',
#  'deputatskiy',
#  'kandiari',
#  'taoudenni',
#  'aswan',
#  'shibetsu',
#  'kenai',
#  'monte escobedo',
#  'port hedland',
#  'kloulklubed',
#  'constitucion',
#  'muros',
#  'srandakan',
#  'kambove',
#  'tarudant',
#  'sidi ali',
#  'san vicente de canete',
#  'hamilton',
#  'dedovichi',
#  'cravo norte',
#  'marcona',
#  'lorengau',
#  'cap malheureux',
#  'axim',
#  'ndjole',
#  'sungurlu',
#  'vesyegonsk',
#  'macusani',
#  'bargal',
#  'erdenet',
#  'knyaze-volkonskoye',
#  'chateauroux',
#  'belmonte',
#  'tripoli',
#  'ivdel',
#  'yurla',
#  'totolapan',
#  'general roca',
#  'smithers',
#  'kodiak',
#  'leningradskiy',
#  'poitiers',
#  'san patricio',
#  'oksfjord',
#  'newport',
#  'kamenskoye',
#  'warwick',
#  'polis',
#  'rostovka',
#  'mareeba',
#  'orikhove',
#  'rakiv lis',
#  'panama city',
#  'ahipara',
#  'narsaq',
#  'san luis',
#  'port hawkesbury',
#  'tando muhammad khan',
#  'lumberton',
#  'druzhba',
#  'kaoma',
#  'harqalah',
#  'katsuura',
#  'vaitupu',
#  'qui nhon',
#  'cubuk',
#  'fort nelson',
#  'khairpur',
#  'namibe',
#  'matara',
#  'bethel',
#  'channel-port aux basques',
#  'kudahuvadhoo',
#  'ndele',
#  'jiazi',
#  'pochutla',
#  'kitimat',
#  'mitsamiouli',
#  'bintulu',
#  'kiama',
#  'guerrero negro',
#  'flin flon',
#  'morant bay',
#  'rocha',
#  'cotonou',
#  'buin',
#  'humberto de campos',
#  'sovetskiy',
#  'kruisfontein',
#  'touros',
#  'mankono',
#  'aksarka',
#  'kieta',
#  'auki',
#  'antofagasta',
#  'la ronge',
#  'ntcheu',
#  'boysun',
#  'arlit',
#  'wanning',
#  'zavitinsk',
#  'ihosy',
#  'mgachi',
#  'turukhansk',
#  'mogadishu',
#  'leh',
#  'chaozhou',
#  'santa cruz de tenerife',
#  'locri',
#  'amalapuram',
#  'tromso',
#  'richards bay',
#  'duz',
#  'leeuwarden',
#  'grants pass',
#  'rungata',
#  'hofn',
#  'birobidzhan',
#  'hobyo',
#  'kalakamati',
#  'dutse',
#  'tilichiki',
#  'malwan',
#  'fallon',
#  'cordoba',
#  'caravelas',
#  'kondoa',
#  'hay river',
#  'hokitika',
#  'colares',
#  'makakilo city',
#  'encruzilhada',
#  'namatanai',
#  'vao',
#  'warqla',
#  'moree',
#  'vardo',
#  'yulara',
#  'hualmay',
#  'grand river south east',
#  'san rafael',
#  'gamba',
#  'denia',
#  'kaitangata',
#  'kinshasa',
#  'xuddur',
#  'juquitiba',
#  'mandalgovi',
#  'tanabe',
#  'prince rupert',
#  'kuche',
#  'marrakesh',
#  'pueblo nuevo',
#  'sheridan',
#  'cabanas',
#  'gat',
#  'jiangyou',
#  'tessalit',
#  'azimur',
#  'erzin',
#  'ravar',
#  'cap-aux-meules',
#  'lata',
#  'nioro',
#  'keuruu',
#  'yorosso',
#  'nivala',
#  'boyolangu',
#  'plerin',
#  'takoradi',
#  'kirkenes',
#  'astana',
#  'sao filipe',
#  'bathsheba',
#  'emerald',
#  'gunupur',
#  'nyurba',
#  'mocuba',
#  'suffolk',
#  'benguela',
#  'sinnamary',
#  'saint-pierre',
#  'bambanglipuro',
#  'yuzhno-yeniseyskiy',
#  'tucupita',
#  'nizwa',
#  'karwar',
#  'taunggyi',
#  'brae',
#  'geraldton',
#  'petropavl',
#  'kuchaman',
#  'muroto',
#  'saint-georges',
#  'deniliquin',
#  'haines junction',
#  'bani',
#  'radishchevo',
#  'ola',
#  'hoopstad',
#  'athabasca',
#  'chapais',
#  'kindu',
#  'okha',
#  'yuci',
#  'san javier',
#  'esmeraldas',
#  'evensk',
#  'beyneu',
#  'myaundzha',
#  'ibirama',
#  'bantry',
#  'amderma',
#  'dolbeau',
#  'hami',
#  'pueblo',
#  'traverse city',
#  'solnechnyy',
#  'hihifo',
#  'arrecife',
#  'zharkovskiy',
#  'qaqortoq',
#  'ganzhou',
#  'corner brook',
#  'afgoye',
#  'utraula',
#  'toppenish',
#  'subaytilah',
#  'el cocuy',
#  'yining',
#  'acarau',
#  'kaeo',
#  'socol',
#  'rey bouba',
#  'port augusta',
#  'roebourne',
#  'moose factory',
#  'acapulco',
#  'olinda',
#  'lannion',
#  'mount gambier',
#  'road town',
#  'tahe',
#  'dordrecht',
#  'umzimvubu',
#  'aktau',
#  'wattegama',
#  'cockburn town',
#  'xiashi',
#  'olafsvik',
#  'zabolotiv',
#  'anito',
#  'vyazemskiy',
#  'tadpatri',
#  'sandwick',
#  'sagua la grande',
#  'isangel',
#  'alausi',
#  'sistranda',
#  'itamarandiba',
#  'belaya gora',
#  'berlevag',
#  'san ramon',
#  'victoria',
#  'port keats',
#  'lokosovo',
#  'flinders',
#  'badvel',
#  'mezen',
#  'nouakchott',
#  'sitka',
#  'lakatoro',
#  'port elizabeth',
#  'batagay',
#  'kampot',
#  'roald',
#  'kentau',
#  'oranjemund',
#  'saint-augustin',
#  'bereda',
#  'innisfail',
#  'champerico',
#  'batemans bay',
#  'port antonio',
#  'khani',
#  'clyde river',
#  'sala consilina',
#  'itacoatiara',
#  'kavieng',
#  'praxedis guerrero',
#  'carutapera',
#  'mecca',
#  'waingapu',
#  'strezhevoy',
#  'yaransk',
#  'komsomolskiy',
#  'promyshlennaya',
#  'moron',
#  'lena',
#  'watsa',
#  'beloha',
#  'san carlos del zulia',
#  'coatesville',
#  'anadyr',
#  'tucurui',
#  'prachuap khiri khan',
#  'polunochnoye',
#  'sibolga',
#  'palanga',
#  'dzhusaly',
#  'sapele',
#  'hilter',
#  'mahajanga',
#  'albion',
#  'grand gaube',
#  'boca do acre',
#  'kaka',
#  'shetpe',
#  'tambacounda',
#  'teguise',
#  'yueyang',
#  'zapolyarnyy',
#  'bijie',
#  'yokadouma',
#  'bilibino',
#  'port blair',
#  'lydenburg',
#  'tumannyy',
#  'waitara',
#  'ha tinh',
#  'loandjili',
#  'dubai',
#  'turinsk',
#  'ygatimi',
#  'vredendal',
#  'abu samrah',
#  'artyk',
#  'ust-kuyga',
#  'novomykolayivka',
#  'sakakah',
#  'dauphin',
#  'maraba',
#  'mokhsogollokh',
#  'dudinka',
#  'ciudad bolivar',
#  'launceston',
#  'chinsali',
#  'torbat-e jam',
#  'zenzeli',
#  'naze',
#  'vitim',
#  'mahina',
#  'ouegoa',
#  'labuhan',
#  'salalah',
#  'altay',
#  'san jose',
#  'san',
#  'majene',
#  'saint-pascal',
#  'bahia blanca',
#  'ust-omchug',
#  'half moon bay',
#  'taksimo',
#  'nome',
#  'port arthur',
#  'novoagansk',
#  'alamogordo',
#  'virginia beach',
#  'ishigaki',
#  'samsun',
#  'praia da vitoria',
#  'kahului',
#  'nazareno',
#  'cockburn harbour',
#  'zeya',
#  'birin',
#  'viligili']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]['lat']
        city_lng = city_weather["coord"]['lon']
        city_max_temp = city_weather["main"]['temp_max']
        city_humidity = city_weather["main"]['humidity']
        city_clouds = city_weather["clouds"]['all']
        city_wind = city_weather["wind"]['speed']
        city_country = city_weather["sys"]['country']
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | ostrovnoy
# Processing Record 3 of Set 1 | talnakh
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 1 | kouqian
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | kars
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | lompoc
# Processing Record 14 of Set 1 | luderitz
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | wyndham
# Processing Record 17 of Set 1 | airai
# Processing Record 18 of Set 1 | nyuksenitsa
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | karpathos
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | preobrazheniye
# Processing Record 24 of Set 1 | margate
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | diphu
# Processing Record 28 of Set 1 | almaznyy
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | pareora
# Processing Record 34 of Set 1 | dadu
# Processing Record 35 of Set 1 | beringovskiy
# Processing Record 36 of Set 1 | xai-xai
# Processing Record 37 of Set 1 | fougeres
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | sorland
# Processing Record 40 of Set 1 | bonavista
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | trinidad
# Processing Record 45 of Set 1 | ingham
# Processing Record 46 of Set 1 | fergus falls
# Processing Record 47 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 0 of Set 2 | guiglo
# Processing Record 1 of Set 2 | bassar
# Processing Record 2 of Set 2 | fortuna
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | mnogovershinnyy
# Processing Record 5 of Set 2 | alice springs
# Processing Record 6 of Set 2 | severo-kurilsk
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | colon
# Processing Record 9 of Set 2 | porto velho
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | coihaique
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | angangxi
# City not found. Skipping...
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | kottagudem
# Processing Record 18 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 2 | kirakira
# Processing Record 20 of Set 2 | liverpool
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 23 of Set 2 | adrar
# Processing Record 24 of Set 2 | tenango
# Processing Record 25 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 2 | samarai
# Processing Record 27 of Set 2 | ullapool
# Processing Record 28 of Set 2 | tura
# Processing Record 29 of Set 2 | pangai
# Processing Record 30 of Set 2 | puro
# Processing Record 31 of Set 2 | boffa
# Processing Record 32 of Set 2 | sharjah
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | marzuq
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | lavrentiya
# Processing Record 38 of Set 2 | araouane
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | castro
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | tiksi
# Processing Record 47 of Set 2 | aklavik
# Processing Record 48 of Set 2 | jahangirpur
# Processing Record 49 of Set 2 | sambava
# Processing Record 0 of Set 3 | souillac
# Processing Record 1 of Set 3 | srednekolymsk
# Processing Record 2 of Set 3 | surt
# Processing Record 3 of Set 3 | rio gallegos
# Processing Record 4 of Set 3 | avera
# Processing Record 5 of Set 3 | vila velha
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | yerbogachen
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | ketchikan
# Processing Record 10 of Set 3 | keshod
# Processing Record 11 of Set 3 | selma
# Processing Record 12 of Set 3 | cayenne
# Processing Record 13 of Set 3 | biu
# Processing Record 14 of Set 3 | harper
# Processing Record 15 of Set 3 | muravlenko
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | broken hill
# Processing Record 18 of Set 3 | noumea
# Processing Record 19 of Set 3 | achisay
# City not found. Skipping...
# Processing Record 20 of Set 3 | manado
# Processing Record 21 of Set 3 | saint johnsbury
# Processing Record 22 of Set 3 | northam
# Processing Record 23 of Set 3 | grindavik
# Processing Record 24 of Set 3 | linfen
# Processing Record 25 of Set 3 | formosa do rio preto
# Processing Record 26 of Set 3 | upernavik
# Processing Record 27 of Set 3 | superior
# Processing Record 28 of Set 3 | bluff
# Processing Record 29 of Set 3 | kamenka
# Processing Record 30 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 3 | pacific grove
# Processing Record 32 of Set 3 | moyale
# Processing Record 33 of Set 3 | meulaboh
# Processing Record 34 of Set 3 | puerto escondido
# Processing Record 35 of Set 3 | ucluelet
# Processing Record 36 of Set 3 | heinola
# Processing Record 37 of Set 3 | hervey bay
# Processing Record 38 of Set 3 | yeppoon
# Processing Record 39 of Set 3 | acajutla
# Processing Record 40 of Set 3 | olinala
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | saint-joseph
# Processing Record 43 of Set 3 | show low
# Processing Record 44 of Set 3 | chara
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | rusape
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | sassandra
# Processing Record 0 of Set 4 | sechura
# Processing Record 1 of Set 4 | toora-khem
# Processing Record 2 of Set 4 | cherskiy
# Processing Record 3 of Set 4 | lanxi
# Processing Record 4 of Set 4 | miranorte
# City not found. Skipping...
# Processing Record 5 of Set 4 | jardim
# Processing Record 6 of Set 4 | traralgon
# Processing Record 7 of Set 4 | bubaque
# Processing Record 8 of Set 4 | yingshang
# City not found. Skipping...
# Processing Record 9 of Set 4 | mildura
# Processing Record 10 of Set 4 | svetlyy
# Processing Record 11 of Set 4 | arraial do cabo
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | aracuai
# Processing Record 16 of Set 4 | atbasar
# Processing Record 17 of Set 4 | marabba
# Processing Record 18 of Set 4 | shahr-e babak
# Processing Record 19 of Set 4 | wawa
# Processing Record 20 of Set 4 | laguna
# Processing Record 21 of Set 4 | torbay
# Processing Record 22 of Set 4 | udachnyy
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | longyearbyen
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | laukaa
# Processing Record 28 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 4 | weyburn
# Processing Record 30 of Set 4 | reconquista
# Processing Record 31 of Set 4 | ilulissat
# Processing Record 32 of Set 4 | devils lake
# Processing Record 33 of Set 4 | gorontalo
# Processing Record 34 of Set 4 | lahij
# Processing Record 35 of Set 4 | saint anthony
# Processing Record 36 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 4 | quatre cocos
# Processing Record 38 of Set 4 | klaksvik
# Processing Record 39 of Set 4 | burica
# City not found. Skipping...
# Processing Record 40 of Set 4 | cedar lake
# Processing Record 41 of Set 4 | vanavara
# Processing Record 42 of Set 4 | faanui
# Processing Record 43 of Set 4 | medyn
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | chojnice
# Processing Record 46 of Set 4 | guapiacu
# Processing Record 47 of Set 4 | susanville
# Processing Record 48 of Set 4 | coahuayana
# Processing Record 49 of Set 4 | alofi
# Processing Record 0 of Set 5 | buraydah
# Processing Record 1 of Set 5 | mansehra
# Processing Record 2 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 5 | ponta do sol
# Processing Record 5 of Set 5 | makinsk
# Processing Record 6 of Set 5 | bambous virieux
# Processing Record 7 of Set 5 | bengkulu
# Processing Record 8 of Set 5 | knysna
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | mahebourg
# Processing Record 11 of Set 5 | san francisco
# Processing Record 12 of Set 5 | eureka
# Processing Record 13 of Set 5 | port lincoln
# Processing Record 14 of Set 5 | bogorodskoye
# Processing Record 15 of Set 5 | nagas
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | husavik
# Processing Record 18 of Set 5 | portland
# Processing Record 19 of Set 5 | solvychegodsk
# Processing Record 20 of Set 5 | vangaindrano
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | qostanay
# Processing Record 23 of Set 5 | sao joao da barra
# Processing Record 24 of Set 5 | baghdad
# Processing Record 25 of Set 5 | itarema
# Processing Record 26 of Set 5 | kosh-agach
# Processing Record 27 of Set 5 | parana
# Processing Record 28 of Set 5 | hailun
# Processing Record 29 of Set 5 | nikolskoye
# Processing Record 30 of Set 5 | san quintin
# Processing Record 31 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 5 | hanna
# Processing Record 33 of Set 5 | cabo san lucas
# Processing Record 34 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 5 | fort smith
# Processing Record 36 of Set 5 | novyy urengoy
# Processing Record 37 of Set 5 | iquique
# Processing Record 38 of Set 5 | qasigiannguit
# Processing Record 39 of Set 5 | deputatskiy
# Processing Record 40 of Set 5 | kandiari
# Processing Record 41 of Set 5 | taoudenni
# Processing Record 42 of Set 5 | aswan
# Processing Record 43 of Set 5 | shibetsu
# Processing Record 44 of Set 5 | kenai
# Processing Record 45 of Set 5 | monte escobedo
# Processing Record 46 of Set 5 | port hedland
# Processing Record 47 of Set 5 | kloulklubed
# Processing Record 48 of Set 5 | constitucion
# Processing Record 49 of Set 5 | muros
# Processing Record 0 of Set 6 | srandakan
# Processing Record 1 of Set 6 | kambove
# Processing Record 2 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 6 | sidi ali
# Processing Record 4 of Set 6 | san vicente de canete
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | dedovichi
# Processing Record 7 of Set 6 | cravo norte
# Processing Record 8 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 6 | lorengau
# Processing Record 10 of Set 6 | cap malheureux
# Processing Record 11 of Set 6 | axim
# Processing Record 12 of Set 6 | ndjole
# Processing Record 13 of Set 6 | sungurlu
# Processing Record 14 of Set 6 | vesyegonsk
# Processing Record 15 of Set 6 | macusani
# Processing Record 16 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 6 | erdenet
# Processing Record 18 of Set 6 | knyaze-volkonskoye
# Processing Record 19 of Set 6 | chateauroux
# Processing Record 20 of Set 6 | belmonte
# Processing Record 21 of Set 6 | tripoli
# Processing Record 22 of Set 6 | ivdel
# Processing Record 23 of Set 6 | yurla
# Processing Record 24 of Set 6 | totolapan
# Processing Record 25 of Set 6 | general roca
# Processing Record 26 of Set 6 | smithers
# Processing Record 27 of Set 6 | kodiak
# Processing Record 28 of Set 6 | leningradskiy
# Processing Record 29 of Set 6 | poitiers
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | oksfjord
# Processing Record 32 of Set 6 | newport
# Processing Record 33 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 6 | warwick
# Processing Record 35 of Set 6 | polis
# Processing Record 36 of Set 6 | rostovka
# Processing Record 37 of Set 6 | mareeba
# Processing Record 38 of Set 6 | orikhove
# Processing Record 39 of Set 6 | rakiv lis
# Processing Record 40 of Set 6 | panama city
# Processing Record 41 of Set 6 | ahipara
# Processing Record 42 of Set 6 | narsaq
# Processing Record 43 of Set 6 | san luis
# Processing Record 44 of Set 6 | port hawkesbury
# Processing Record 45 of Set 6 | tando muhammad khan
# Processing Record 46 of Set 6 | lumberton
# Processing Record 47 of Set 6 | druzhba
# Processing Record 48 of Set 6 | kaoma
# Processing Record 49 of Set 6 | harqalah
# Processing Record 0 of Set 7 | katsuura
# Processing Record 1 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 7 | qui nhon
# Processing Record 3 of Set 7 | cubuk
# Processing Record 4 of Set 7 | fort nelson
# Processing Record 5 of Set 7 | khairpur
# Processing Record 6 of Set 7 | namibe
# Processing Record 7 of Set 7 | matara
# Processing Record 8 of Set 7 | bethel
# Processing Record 9 of Set 7 | channel-port aux basques
# Processing Record 10 of Set 7 | kudahuvadhoo
# Processing Record 11 of Set 7 | ndele
# Processing Record 12 of Set 7 | jiazi
# Processing Record 13 of Set 7 | pochutla
# Processing Record 14 of Set 7 | kitimat
# Processing Record 15 of Set 7 | mitsamiouli
# Processing Record 16 of Set 7 | bintulu
# Processing Record 17 of Set 7 | kiama
# Processing Record 18 of Set 7 | guerrero negro
# Processing Record 19 of Set 7 | flin flon
# Processing Record 20 of Set 7 | morant bay
# Processing Record 21 of Set 7 | rocha
# Processing Record 22 of Set 7 | cotonou
# Processing Record 23 of Set 7 | buin
# Processing Record 24 of Set 7 | humberto de campos
# Processing Record 25 of Set 7 | sovetskiy
# Processing Record 26 of Set 7 | kruisfontein
# Processing Record 27 of Set 7 | touros
# Processing Record 28 of Set 7 | mankono
# Processing Record 29 of Set 7 | aksarka
# Processing Record 30 of Set 7 | kieta
# Processing Record 31 of Set 7 | auki
# Processing Record 32 of Set 7 | antofagasta
# Processing Record 33 of Set 7 | la ronge
# Processing Record 34 of Set 7 | ntcheu
# Processing Record 35 of Set 7 | boysun
# Processing Record 36 of Set 7 | arlit
# Processing Record 37 of Set 7 | wanning
# Processing Record 38 of Set 7 | zavitinsk
# Processing Record 39 of Set 7 | ihosy
# Processing Record 40 of Set 7 | mgachi
# Processing Record 41 of Set 7 | turukhansk
# Processing Record 42 of Set 7 | mogadishu
# Processing Record 43 of Set 7 | leh
# Processing Record 44 of Set 7 | chaozhou
# Processing Record 45 of Set 7 | santa cruz de tenerife
# Processing Record 46 of Set 7 | locri
# Processing Record 47 of Set 7 | amalapuram
# Processing Record 48 of Set 7 | tromso
# Processing Record 49 of Set 7 | richards bay
# Processing Record 0 of Set 8 | duz
# City not found. Skipping...
# Processing Record 1 of Set 8 | leeuwarden
# Processing Record 2 of Set 8 | grants pass
# Processing Record 3 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 8 | hofn
# Processing Record 5 of Set 8 | birobidzhan
# Processing Record 6 of Set 8 | hobyo
# Processing Record 7 of Set 8 | kalakamati
# Processing Record 8 of Set 8 | dutse
# Processing Record 9 of Set 8 | tilichiki
# Processing Record 10 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 8 | fallon
# Processing Record 12 of Set 8 | cordoba
# Processing Record 13 of Set 8 | caravelas
# Processing Record 14 of Set 8 | kondoa
# Processing Record 15 of Set 8 | hay river
# Processing Record 16 of Set 8 | hokitika
# Processing Record 17 of Set 8 | colares
# Processing Record 18 of Set 8 | makakilo city
# Processing Record 19 of Set 8 | encruzilhada
# Processing Record 20 of Set 8 | namatanai
# Processing Record 21 of Set 8 | vao
# Processing Record 22 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 8 | moree
# Processing Record 24 of Set 8 | vardo
# Processing Record 25 of Set 8 | yulara
# Processing Record 26 of Set 8 | hualmay
# Processing Record 27 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 8 | san rafael
# Processing Record 29 of Set 8 | gamba
# Processing Record 30 of Set 8 | denia
# Processing Record 31 of Set 8 | kaitangata
# Processing Record 32 of Set 8 | kinshasa
# Processing Record 33 of Set 8 | xuddur
# Processing Record 34 of Set 8 | juquitiba
# Processing Record 35 of Set 8 | mandalgovi
# Processing Record 36 of Set 8 | tanabe
# Processing Record 37 of Set 8 | prince rupert
# Processing Record 38 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 8 | marrakesh
# Processing Record 40 of Set 8 | pueblo nuevo
# Processing Record 41 of Set 8 | sheridan
# Processing Record 42 of Set 8 | cabanas
# Processing Record 43 of Set 8 | gat
# Processing Record 44 of Set 8 | jiangyou
# Processing Record 45 of Set 8 | tessalit
# Processing Record 46 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 47 of Set 8 | erzin
# Processing Record 48 of Set 8 | ravar
# Processing Record 49 of Set 8 | cap-aux-meules
# Processing Record 0 of Set 9 | lata
# Processing Record 1 of Set 9 | nioro
# Processing Record 2 of Set 9 | keuruu
# Processing Record 3 of Set 9 | yorosso
# Processing Record 4 of Set 9 | nivala
# Processing Record 5 of Set 9 | boyolangu
# Processing Record 6 of Set 9 | plerin
# Processing Record 7 of Set 9 | takoradi
# Processing Record 8 of Set 9 | kirkenes
# Processing Record 9 of Set 9 | astana
# Processing Record 10 of Set 9 | sao filipe
# Processing Record 11 of Set 9 | bathsheba
# Processing Record 12 of Set 9 | emerald
# Processing Record 13 of Set 9 | gunupur
# Processing Record 14 of Set 9 | nyurba
# Processing Record 15 of Set 9 | mocuba
# Processing Record 16 of Set 9 | suffolk
# Processing Record 17 of Set 9 | benguela
# Processing Record 18 of Set 9 | sinnamary
# Processing Record 19 of Set 9 | saint-pierre
# Processing Record 20 of Set 9 | bambanglipuro
# Processing Record 21 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | tucupita
# Processing Record 23 of Set 9 | nizwa
# Processing Record 24 of Set 9 | karwar
# Processing Record 25 of Set 9 | taunggyi
# Processing Record 26 of Set 9 | brae
# Processing Record 27 of Set 9 | geraldton
# Processing Record 28 of Set 9 | petropavl
# Processing Record 29 of Set 9 | kuchaman
# Processing Record 30 of Set 9 | muroto
# Processing Record 31 of Set 9 | saint-georges
# Processing Record 32 of Set 9 | deniliquin
# Processing Record 33 of Set 9 | haines junction
# Processing Record 34 of Set 9 | bani
# Processing Record 35 of Set 9 | radishchevo
# Processing Record 36 of Set 9 | ola
# Processing Record 37 of Set 9 | hoopstad
# Processing Record 38 of Set 9 | athabasca
# Processing Record 39 of Set 9 | chapais
# Processing Record 40 of Set 9 | kindu
# Processing Record 41 of Set 9 | okha
# Processing Record 42 of Set 9 | yuci
# Processing Record 43 of Set 9 | san javier
# Processing Record 44 of Set 9 | esmeraldas
# Processing Record 45 of Set 9 | evensk
# Processing Record 46 of Set 9 | beyneu
# Processing Record 47 of Set 9 | myaundzha
# Processing Record 48 of Set 9 | ibirama
# Processing Record 49 of Set 9 | bantry
# Processing Record 0 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 10 | hami
# Processing Record 3 of Set 10 | pueblo
# Processing Record 4 of Set 10 | traverse city
# Processing Record 5 of Set 10 | solnechnyy
# Processing Record 6 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 10 | arrecife
# Processing Record 8 of Set 10 | zharkovskiy
# Processing Record 9 of Set 10 | qaqortoq
# Processing Record 10 of Set 10 | ganzhou
# Processing Record 11 of Set 10 | corner brook
# Processing Record 12 of Set 10 | afgoye
# City not found. Skipping...
# Processing Record 13 of Set 10 | utraula
# Processing Record 14 of Set 10 | toppenish
# Processing Record 15 of Set 10 | subaytilah
# City not found. Skipping...
# Processing Record 16 of Set 10 | el cocuy
# Processing Record 17 of Set 10 | yining
# Processing Record 18 of Set 10 | acarau
# Processing Record 19 of Set 10 | kaeo
# Processing Record 20 of Set 10 | socol
# Processing Record 21 of Set 10 | rey bouba
# Processing Record 22 of Set 10 | port augusta
# Processing Record 23 of Set 10 | roebourne
# Processing Record 24 of Set 10 | moose factory
# Processing Record 25 of Set 10 | acapulco
# Processing Record 26 of Set 10 | olinda
# Processing Record 27 of Set 10 | lannion
# Processing Record 28 of Set 10 | mount gambier
# Processing Record 29 of Set 10 | road town
# Processing Record 30 of Set 10 | tahe
# Processing Record 31 of Set 10 | dordrecht
# Processing Record 32 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 10 | aktau
# Processing Record 34 of Set 10 | wattegama
# Processing Record 35 of Set 10 | cockburn town
# Processing Record 36 of Set 10 | xiashi
# Processing Record 37 of Set 10 | olafsvik
# Processing Record 38 of Set 10 | zabolotiv
# Processing Record 39 of Set 10 | anito
# Processing Record 40 of Set 10 | vyazemskiy
# Processing Record 41 of Set 10 | tadpatri
# Processing Record 42 of Set 10 | sandwick
# Processing Record 43 of Set 10 | sagua la grande
# Processing Record 44 of Set 10 | isangel
# Processing Record 45 of Set 10 | alausi
# Processing Record 46 of Set 10 | sistranda
# Processing Record 47 of Set 10 | itamarandiba
# Processing Record 48 of Set 10 | belaya gora
# Processing Record 49 of Set 10 | berlevag
# Processing Record 0 of Set 11 | san ramon
# Processing Record 1 of Set 11 | victoria
# Processing Record 2 of Set 11 | port keats
# Processing Record 3 of Set 11 | lokosovo
# Processing Record 4 of Set 11 | flinders
# Processing Record 5 of Set 11 | badvel
# Processing Record 6 of Set 11 | mezen
# Processing Record 7 of Set 11 | nouakchott
# Processing Record 8 of Set 11 | sitka
# Processing Record 9 of Set 11 | lakatoro
# Processing Record 10 of Set 11 | port elizabeth
# Processing Record 11 of Set 11 | batagay
# Processing Record 12 of Set 11 | kampot
# Processing Record 13 of Set 11 | roald
# Processing Record 14 of Set 11 | kentau
# Processing Record 15 of Set 11 | oranjemund
# Processing Record 16 of Set 11 | saint-augustin
# Processing Record 17 of Set 11 | bereda
# Processing Record 18 of Set 11 | innisfail
# Processing Record 19 of Set 11 | champerico
# Processing Record 20 of Set 11 | batemans bay
# Processing Record 21 of Set 11 | port antonio
# Processing Record 22 of Set 11 | khani
# Processing Record 23 of Set 11 | clyde river
# Processing Record 24 of Set 11 | sala consilina
# Processing Record 25 of Set 11 | itacoatiara
# Processing Record 26 of Set 11 | kavieng
# Processing Record 27 of Set 11 | praxedis guerrero
# Processing Record 28 of Set 11 | carutapera
# Processing Record 29 of Set 11 | mecca
# Processing Record 30 of Set 11 | waingapu
# Processing Record 31 of Set 11 | strezhevoy
# Processing Record 32 of Set 11 | yaransk
# Processing Record 33 of Set 11 | komsomolskiy
# Processing Record 34 of Set 11 | promyshlennaya
# Processing Record 35 of Set 11 | moron
# Processing Record 36 of Set 11 | lena
# Processing Record 37 of Set 11 | watsa
# Processing Record 38 of Set 11 | beloha
# Processing Record 39 of Set 11 | san carlos del zulia
# Processing Record 40 of Set 11 | coatesville
# Processing Record 41 of Set 11 | anadyr
# Processing Record 42 of Set 11 | tucurui
# Processing Record 43 of Set 11 | prachuap khiri khan
# Processing Record 44 of Set 11 | polunochnoye
# Processing Record 45 of Set 11 | sibolga
# Processing Record 46 of Set 11 | palanga
# Processing Record 47 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 11 | sapele
# Processing Record 49 of Set 11 | hilter
# Processing Record 0 of Set 12 | mahajanga
# Processing Record 1 of Set 12 | albion
# Processing Record 2 of Set 12 | grand gaube
# Processing Record 3 of Set 12 | boca do acre
# Processing Record 4 of Set 12 | kaka
# Processing Record 5 of Set 12 | shetpe
# Processing Record 6 of Set 12 | tambacounda
# Processing Record 7 of Set 12 | teguise
# Processing Record 8 of Set 12 | yueyang
# Processing Record 9 of Set 12 | zapolyarnyy
# Processing Record 10 of Set 12 | bijie
# Processing Record 11 of Set 12 | yokadouma
# Processing Record 12 of Set 12 | bilibino
# Processing Record 13 of Set 12 | port blair
# Processing Record 14 of Set 12 | lydenburg
# Processing Record 15 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 12 | waitara
# Processing Record 17 of Set 12 | ha tinh
# Processing Record 18 of Set 12 | loandjili
# Processing Record 19 of Set 12 | dubai
# Processing Record 20 of Set 12 | turinsk
# Processing Record 21 of Set 12 | ygatimi
# Processing Record 22 of Set 12 | vredendal
# Processing Record 23 of Set 12 | abu samrah
# Processing Record 24 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 25 of Set 12 | ust-kuyga
# Processing Record 26 of Set 12 | novomykolayivka
# Processing Record 27 of Set 12 | sakakah
# Processing Record 28 of Set 12 | dauphin
# Processing Record 29 of Set 12 | maraba
# Processing Record 30 of Set 12 | mokhsogollokh
# Processing Record 31 of Set 12 | dudinka
# Processing Record 32 of Set 12 | ciudad bolivar
# Processing Record 33 of Set 12 | launceston
# Processing Record 34 of Set 12 | chinsali
# Processing Record 35 of Set 12 | torbat-e jam
# Processing Record 36 of Set 12 | zenzeli
# Processing Record 37 of Set 12 | naze
# Processing Record 38 of Set 12 | vitim
# Processing Record 39 of Set 12 | mahina
# Processing Record 40 of Set 12 | ouegoa
# Processing Record 41 of Set 12 | labuhan
# Processing Record 42 of Set 12 | salalah
# Processing Record 43 of Set 12 | altay
# Processing Record 44 of Set 12 | san jose
# Processing Record 45 of Set 12 | san
# Processing Record 46 of Set 12 | majene
# Processing Record 47 of Set 12 | saint-pascal
# City not found. Skipping...
# Processing Record 48 of Set 12 | bahia blanca
# Processing Record 49 of Set 12 | ust-omchug
# Processing Record 0 of Set 13 | half moon bay
# Processing Record 1 of Set 13 | taksimo
# Processing Record 2 of Set 13 | nome
# Processing Record 3 of Set 13 | port arthur
# Processing Record 4 of Set 13 | novoagansk
# Processing Record 5 of Set 13 | alamogordo
# Processing Record 6 of Set 13 | virginia beach
# Processing Record 7 of Set 13 | ishigaki
# Processing Record 8 of Set 13 | samsun
# Processing Record 9 of Set 13 | praia da vitoria
# Processing Record 10 of Set 13 | kahului
# Processing Record 11 of Set 13 | nazareno
# Processing Record 12 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 13 | zeya
# Processing Record 14 of Set 13 | birin
# Processing Record 15 of Set 13 | viligili
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 city_data
# Out:
# [{'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 289.4,
#   'Humidity': 62,
#   'Cloudiness': 50,
#   'Wind Speed': 2.58,
#   'Country': 'ZA',
#   'Date': 1670263188},
#  {'City': 'ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 265.9,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 8.57,
#   'Country': 'RU',
#   'Date': 1670263189},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 269.38,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.32,
#   'Country': 'RU',
#   'Date': 1670263189},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 283.46,
#   'Humidity': 76,
#   'Cloudiness': 15,
#   'Wind Speed': 4.67,
#   'Country': 'AU',
#   'Date': 1670263065},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 284.94,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 11.83,
#   'Country': 'AR',
#   'Date': 1670263066},
#  {'City': 'saint george',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 283.39,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1670262895},
#  {'City': 'kouqian',
#   'Lat': 43.6391,
#   'Lng': 126.4578,
#   'Max Temp': 261.16,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 3.66,
#   'Country': 'CN',
#   'Date': 1670263190},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 286.06,
#   'Humidity': 89,
#   'Cloudiness': 51,
#   'Wind Speed': 5.39,
#   'Country': 'AU',
#   'Date': 1670262999},
#  {'City': 'khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 241.13,
#   'Humidity': 100,
#   'Cloudiness': 28,
#   'Wind Speed': 1.52,
#   'Country': 'RU',
#   'Date': 1670263191},
#  {'City': 'kars',
#   'Lat': 40.602,
#   'Lng': 43.095,
#   'Max Temp': 271.01,
#   'Humidity': 87,
#   'Cloudiness': 95,
#   'Wind Speed': 1.23,
#   'Country': 'TR',
#   'Date': 1670262919},
#  {'City': 'kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 295.33,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1670263191},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 288.58,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 0.45,
#   'Country': 'US',
#   'Date': 1670263192},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 290.55,
#   'Humidity': 63,
#   'Cloudiness': 1,
#   'Wind Speed': 11.6,
#   'Country': 'NA',
#   'Date': 1670263192},
#  {'City': 'chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 236.36,
#   'Humidity': 98,
#   'Cloudiness': 59,
#   'Wind Speed': 3.92,
#   'Country': 'RU',
#   'Date': 1670263193},
#  {'City': 'wyndham',
#   'Lat': 37.6985,
#   'Lng': -77.6125,
#   'Max Temp': 284.23,
#   'Humidity': 51,
#   'Cloudiness': 95,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1670263193},
#  {'City': 'airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 288.32,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 0.75,
#   'Country': 'TL',
#   'Date': 1670263084},
#  {'City': 'nyuksenitsa',
#   'Lat': 60.4128,
#   'Lng': 44.2397,
#   'Max Temp': 264.26,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 3.32,
#   'Country': 'RU',
#   'Date': 1670263194},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 296.24,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'TO',
#   'Date': 1670263077},
#  {'City': 'cape town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 293.3,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 7.72,
#   'Country': 'ZA',
#   'Date': 1670263111},
#  {'City': 'karpathos',
#   'Lat': 35.507,
#   'Lng': 27.2132,
#   'Max Temp': 289.13,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'GR',
#   'Date': 1670263195},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 280.38,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'US',
#   'Date': 1670263160},
#  {'City': 'preobrazheniye',
#   'Lat': 42.9019,
#   'Lng': 133.9064,
#   'Max Temp': 265.18,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 3.54,
#   'Country': 'RU',
#   'Date': 1670263195},
#  {'City': 'margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 280.32,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'GB',
#   'Date': 1670263196},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 298.06,
#   'Humidity': 78,
#   'Cloudiness': 82,
#   'Wind Speed': 7.36,
#   'Country': 'PF',
#   'Date': 1670263034},
#  {'City': 'esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 288.91,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.19,
#   'Country': 'AU',
#   'Date': 1670263196},
#  {'City': 'diphu',
#   'Lat': 25.8333,
#   'Lng': 93.4333,
#   'Max Temp': 288.5,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 0.23,
#   'Country': 'IN',
#   'Date': 1670263197},
#  {'City': 'almaznyy',
#   'Lat': 48.0448,
#   'Lng': 40.045,
#   'Max Temp': 265.95,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 5.71,
#   'Country': 'RU',
#   'Date': 1670263197},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 301.06,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'MY',
#   'Date': 1670263198},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 283.21,
#   'Humidity': 43,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'CL',
#   'Date': 1670263198},
#  {'City': 'mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 283.42,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.35,
#   'Country': 'NZ',
#   'Date': 1670263096},
#  {'City': 'rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 297.12,
#   'Humidity': 81,
#   'Cloudiness': 83,
#   'Wind Speed': 5.81,
#   'Country': 'PF',
#   'Date': 1670263054},
#  {'City': 'pareora',
#   'Lat': -44.4871,
#   'Lng': 171.2132,
#   'Max Temp': 284.92,
#   'Humidity': 97,
#   'Cloudiness': 61,
#   'Wind Speed': 1.46,
#   'Country': 'NZ',
#   'Date': 1670263199},
#  {'City': 'dadu',
#   'Lat': 26.7329,
#   'Lng': 67.7763,
#   'Max Temp': 293.57,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 0.6,
#   'Country': 'PK',
#   'Date': 1670263199},
#  {'City': 'beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 272.51,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 18.42,
#   'Country': 'RU',
#   'Date': 1670263200},
#  {'City': 'xai-xai',
#   'Lat': -25.0519,
#   'Lng': 33.6442,
#   'Max Temp': 300.96,
#   'Humidity': 71,
#   'Cloudiness': 59,
#   'Wind Speed': 1.25,
#   'Country': 'MZ',
#   'Date': 1670263200},
#  {'City': 'fougeres',
#   'Lat': 48.35,
#   'Lng': -1.2,
#   'Max Temp': 277.07,
#   'Humidity': 88,
#   'Cloudiness': 73,
#   'Wind Speed': 3.09,
#   'Country': 'FR',
#   'Date': 1670263201},
#  {'City': 'sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 278.07,
#   'Humidity': 86,
#   'Cloudiness': 99,
#   'Wind Speed': 18.78,
#   'Country': 'NO',
#   'Date': 1670263203},
#  {'City': 'bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 277.33,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'CA',
#   'Date': 1670263204},
#  {'City': 'mar del plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 306.39,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 6.26,
#   'Country': 'AR',
#   'Date': 1670263104},
#  {'City': 'hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 284.07,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'AU',
#   'Date': 1670263205},
#  {'City': 'east london',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 290.67,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'ZA',
#   'Date': 1670263169},
#  {'City': 'trinidad',
#   'Lat': -14.8333,
#   'Lng': -64.9,
#   'Max Temp': 300.14,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 7.72,
#   'Country': 'BO',
#   'Date': 1670263207},
#  {'City': 'ingham',
#   'Lat': 42.6,
#   'Lng': -84.3833,
#   'Max Temp': 277.14,
#   'Humidity': 58,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1670263209},
#  {'City': 'fergus falls',
#   'Lat': 46.283,
#   'Lng': -96.0776,
#   'Max Temp': 267.19,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 8.75,
#   'Country': 'US',
#   'Date': 1670263210},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 290.82,
#   'Humidity': 62,
#   'Cloudiness': 50,
#   'Wind Speed': 2.14,
#   'Country': 'ZA',
#   'Date': 1670263211},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 246.15,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 10.8,
#   'Country': 'CA',
#   'Date': 1670263000},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 295.12,
#   'Humidity': 86,
#   'Cloudiness': 71,
#   'Wind Speed': 3.58,
#   'Country': 'EC',
#   'Date': 1670263212},
#  {'City': 'guiglo',
#   'Lat': 6.5456,
#   'Lng': -7.4966,
#   'Max Temp': 300.15,
#   'Humidity': 73,
#   'Cloudiness': 95,
#   'Wind Speed': 1.21,
#   'Country': 'CI',
#   'Date': 1670263212},
#  {'City': 'bassar',
#   'Lat': 9.25,
#   'Lng': 0.7833,
#   'Max Temp': 303.12,
#   'Humidity': 25,
#   'Cloudiness': 69,
#   'Wind Speed': 1.78,
#   'Country': 'TG',
#   'Date': 1670263213},
#  {'City': 'fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 281.34,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1670263214},
#  {'City': 'saint-philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 297.92,
#   'Humidity': 80,
#   'Cloudiness': 81,
#   'Wind Speed': 5.07,
#   'Country': 'RE',
#   'Date': 1670263181},
#  {'City': 'mnogovershinnyy',
#   'Lat': 53.9353,
#   'Lng': 139.9242,
#   'Max Temp': 250.26,
#   'Humidity': 90,
#   'Cloudiness': 89,
#   'Wind Speed': 3.04,
#   'Country': 'RU',
#   'Date': 1670263215},
#  {'City': 'alice springs',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 292.9,
#   'Humidity': 32,
#   'Cloudiness': 22,
#   'Wind Speed': 2.06,
#   'Country': 'AU',
#   'Date': 1670263216},
#  {'City': 'severo-kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 268.08,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Country': 'RU',
#   'Date': 1670263217},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 280.34,
#   'Humidity': 50,
#   'Cloudiness': 44,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1670263202},
#  {'City': 'colon',
#   'Lat': 9.3592,
#   'Lng': -79.9014,
#   'Max Temp': 299.51,
#   'Humidity': 83,
#   'Cloudiness': 84,
#   'Wind Speed': 1.34,
#   'Country': 'PA',
#   'Date': 1670263218},
#  {'City': 'porto velho',
#   'Lat': -8.7619,
#   'Lng': -63.9039,
#   'Max Temp': 299.18,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'BR',
#   'Date': 1670263018},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 283.87,
#   'Humidity': 62,
#   'Cloudiness': 99,
#   'Wind Speed': 1.57,
#   'Country': 'AU',
#   'Date': 1670263070},
#  {'City': 'coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 284.43,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 2.94,
#   'Country': 'CL',
#   'Date': 1670263220},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 290.37,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 7.15,
#   'Country': 'PT',
#   'Date': 1670263220},
#  {'City': 'provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 269.66,
#   'Humidity': 92,
#   'Cloudiness': 83,
#   'Wind Speed': 7.27,
#   'Country': 'RU',
#   'Date': 1670263221},
#  {'City': 'butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 300.08,
#   'Humidity': 82,
#   'Cloudiness': 85,
#   'Wind Speed': 7.66,
#   'Country': 'KI',
#   'Date': 1670263078},
#  {'City': 'kottagudem',
#   'Lat': 17.55,
#   'Lng': 80.6333,
#   'Max Temp': 293.48,
#   'Humidity': 66,
#   'Cloudiness': 32,
#   'Wind Speed': 0.42,
#   'Country': 'IN',
#   'Date': 1670263223},
#  {'City': 'kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 299.13,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.87,
#   'Country': 'SB',
#   'Date': 1670263224},
#  {'City': 'liverpool',
#   'Lat': 53.4106,
#   'Lng': -2.9779,
#   'Max Temp': 280.12,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 4.63,
#   'Country': 'GB',
#   'Date': 1670263179},
#  {'City': 'saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 245.59,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Country': 'RU',
#   'Date': 1670263226},
#  {'City': 'adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 298.88,
#   'Humidity': 23,
#   'Cloudiness': 16,
#   'Wind Speed': 1.71,
#   'Country': 'MR',
#   'Date': 1670263217},
#  {'City': 'tenango',
#   'Lat': 18.65,
#   'Lng': -98.1833,
#   'Max Temp': 298.43,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 1.82,
#   'Country': 'MX',
#   'Date': 1670263229},
#  {'City': 'samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 300.07,
#   'Humidity': 76,
#   'Cloudiness': 96,
#   'Wind Speed': 3.24,
#   'Country': 'PG',
#   'Date': 1670263230},
#  {'City': 'ullapool',
#   'Lat': 57.8987,
#   'Lng': -5.1604,
#   'Max Temp': 275.01,
#   'Humidity': 81,
#   'Cloudiness': 84,
#   'Wind Speed': 0.95,
#   'Country': 'GB',
#   'Date': 1670263230},
#  {'City': 'tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 289.53,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 1.39,
#   'Country': 'IN',
#   'Date': 1670263231},
#  {'City': 'pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 299.67,
#   'Humidity': 73,
#   'Cloudiness': 96,
#   'Wind Speed': 1.1,
#   'Country': 'TO',
#   'Date': 1670263232},
#  {'City': 'puro',
#   'Lat': 12.4841,
#   'Lng': 123.3827,
#   'Max Temp': 298.76,
#   'Humidity': 86,
#   'Cloudiness': 56,
#   'Wind Speed': 4.1,
#   'Country': 'PH',
#   'Date': 1670263233},
#  {'City': 'boffa',
#   'Lat': 10.1667,
#   'Lng': -14.0333,
#   'Max Temp': 303.43,
#   'Humidity': 71,
#   'Cloudiness': 72,
#   'Wind Speed': 2.41,
#   'Country': 'GN',
#   'Date': 1670263233},
#  {'City': 'sharjah',
#   'Lat': 25.3573,
#   'Lng': 55.4033,
#   'Max Temp': 300.14,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'AE',
#   'Date': 1670263072},
#  {'City': 'dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 269.67,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.35,
#   'Country': 'RU',
#   'Date': 1670263235},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 243.24,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'CA',
#   'Date': 1670263072},
#  {'City': 'marzuq',
#   'Lat': 14.4,
#   'Lng': 46.4667,
#   'Max Temp': 290.83,
#   'Humidity': 50,
#   'Cloudiness': 5,
#   'Wind Speed': 0.92,
#   'Country': 'YE',
#   'Date': 1670263236},
#  {'City': 'tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 265.86,
#   'Humidity': 65,
#   'Cloudiness': 96,
#   'Wind Speed': 2.7,
#   'Country': 'GL',
#   'Date': 1670263169},
#  {'City': 'lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 267.71,
#   'Humidity': 87,
#   'Cloudiness': 34,
#   'Wind Speed': 1.66,
#   'Country': 'RU',
#   'Date': 1670263238},
#  {'City': 'araouane',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 301.35,
#   'Humidity': 15,
#   'Cloudiness': 100,
#   'Wind Speed': 0.93,
#   'Country': 'ML',
#   'Date': 1670263238},
#  {'City': 'hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 297.75,
#   'Humidity': 86,
#   'Cloudiness': 92,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1670263056},
#  {'City': 'castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 294.56,
#   'Humidity': 86,
#   'Cloudiness': 97,
#   'Wind Speed': 3.22,
#   'Country': 'BR',
#   'Date': 1670263239},
#  {'City': 'chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 299,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 4.85,
#   'Country': 'UY',
#   'Date': 1670263057},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 300.74,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 3.65,
#   'Country': 'MV',
#   'Date': 1670263240},
#  {'City': 'norman wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 240.61,
#   'Humidity': 93,
#   'Cloudiness': 30,
#   'Wind Speed': 3.78,
#   'Country': 'CA',
#   'Date': 1670263241},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 296.18,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'CK',
#   'Date': 1670263242},
#  {'City': 'cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 296.96,
#   'Humidity': 81,
#   'Cloudiness': 74,
#   'Wind Speed': 5.22,
#   'Country': 'BR',
#   'Date': 1670263243},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 248.97,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.18,
#   'Country': 'RU',
#   'Date': 1670263243},
#  {'City': 'aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 247.66,
#   'Humidity': 86,
#   'Cloudiness': 43,
#   'Wind Speed': 9.97,
#   'Country': 'CA',
#   'Date': 1670263057},
#  {'City': 'jahangirpur',
#   'Lat': 28.1833,
#   'Lng': 77.7167,
#   'Max Temp': 289.47,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 2.01,
#   'Country': 'IN',
#   'Date': 1670263244},
#  {'City': 'sambava',
#   'Lat': -14.2667,
#   'Lng': 50.1667,
#   'Max Temp': 297.6,
#   'Humidity': 88,
#   'Cloudiness': 6,
#   'Wind Speed': 5.54,
#   'Country': 'MG',
#   'Date': 1670263245},
#  {'City': 'souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 298.36,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 4.63,
#   'Country': 'MU',
#   'Date': 1670263245},
#  {'City': 'srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': 229.88,
#   'Humidity': 100,
#   'Cloudiness': 64,
#   'Wind Speed': 0.62,
#   'Country': 'RU',
#   'Date': 1670263246},
#  {'City': 'surt',
#   'Lat': 31.2089,
#   'Lng': 16.5887,
#   'Max Temp': 293.52,
#   'Humidity': 64,
#   'Cloudiness': 62,
#   'Wind Speed': 2.77,
#   'Country': 'LY',
#   'Date': 1670263247},
#  {'City': 'rio gallegos',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 286.75,
#   'Humidity': 35,
#   'Cloudiness': 94,
#   'Wind Speed': 9.53,
#   'Country': 'AR',
#   'Date': 1670263247},
#  {'City': 'avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 283.92,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.41,
#   'Country': 'US',
#   'Date': 1670263247},
#  {'City': 'vila velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 299.79,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 6.74,
#   'Country': 'BR',
#   'Date': 1670263228},
#  {'City': 'yerbogachen',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 262.29,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.56,
#   'Country': 'RU',
#   'Date': 1670263249},
#  {'City': 'barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 276.23,
#   'Humidity': 66,
#   'Cloudiness': 96,
#   'Wind Speed': 13.71,
#   'Country': 'US',
#   'Date': 1670263002},
#  {'City': 'ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 272.27,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 1.23,
#   'Country': 'US',
#   'Date': 1670263250},
#  {'City': 'keshod',
#   'Lat': 21.3,
#   'Lng': 70.25,
#   'Max Temp': 292.88,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 3.74,
#   'Country': 'IN',
#   'Date': 1670263250},
#  {'City': 'selma',
#   'Lat': 36.5708,
#   'Lng': -119.6121,
#   'Max Temp': 287.39,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1670263251},
#  {'City': 'cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 303.17,
#   'Humidity': 70,
#   'Cloudiness': 93,
#   'Wind Speed': 4.63,
#   'Country': 'GF',
#   'Date': 1670263034},
#  {'City': 'biu',
#   'Lat': 10.6129,
#   'Lng': 12.1946,
#   'Max Temp': 297.73,
#   'Humidity': 16,
#   'Cloudiness': 84,
#   'Wind Speed': 3.28,
#   'Country': 'NG',
#   'Date': 1670263252},
#  {'City': 'harper',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 299.62,
#   'Humidity': 81,
#   'Cloudiness': 77,
#   'Wind Speed': 2.25,
#   'Country': 'LR',
#   'Date': 1670263252},
#  {'City': 'muravlenko',
#   'Lat': 63.7898,
#   'Lng': 74.523,
#   'Max Temp': 258.01,
#   'Humidity': 96,
#   'Cloudiness': 79,
#   'Wind Speed': 4.95,
#   'Country': 'RU',
#   'Date': 1670263253},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 293.85,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 7.85,
#   'Country': 'AU',
#   'Date': 1670263253},
#  {'City': 'broken hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 289.99,
#   'Humidity': 41,
#   'Cloudiness': 67,
#   'Wind Speed': 5.67,
#   'Country': 'AU',
#   'Date': 1670263254},
#  {'City': 'noumea',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 299.82,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.01,
#   'Country': 'NC',
#   'Date': 1670263254},
#  {'City': 'manado',
#   'Lat': 1.487,
#   'Lng': 124.8455,
#   'Max Temp': 297.58,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 0.51,
#   'Country': 'ID',
#   'Date': 1670263255},
#  {'City': 'saint johnsbury',
#   'Lat': 44.4192,
#   'Lng': -72.0151,
#   'Max Temp': 279.79,
#   'Humidity': 52,
#   'Cloudiness': 13,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1670263124},
#  {'City': 'northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 280.59,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.12,
#   'Country': 'GB',
#   'Date': 1670263256},
#  {'City': 'grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 272.41,
#   'Humidity': 100,
#   'Cloudiness': 5,
#   'Wind Speed': 1.54,
#   'Country': 'IS',
#   'Date': 1670263095},
#  {'City': 'linfen',
#   'Lat': 36.0889,
#   'Lng': 111.5189,
#   'Max Temp': 276.12,
#   'Humidity': 38,
#   'Cloudiness': 2,
#   'Wind Speed': 0.28,
#   'Country': 'CN',
#   'Date': 1670263229},
#  {'City': 'formosa do rio preto',
#   'Lat': -11.0483,
#   'Lng': -45.1931,
#   'Max Temp': 299.56,
#   'Humidity': 72,
#   'Cloudiness': 84,
#   'Wind Speed': 3.06,
#   'Country': 'BR',
#   'Date': 1670263257},
#  {'City': 'upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 271.89,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.47,
#   'Country': 'GL',
#   'Date': 1670263258},
#  {'City': 'superior',
#   'Lat': 46.7208,
#   'Lng': -92.1041,
#   'Max Temp': 270.35,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1670263021},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 283.6,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.1,
#   'Country': 'NZ',
#   'Date': 1670263038},
#  {'City': 'kamenka',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 264.57,
#   'Humidity': 56,
#   'Cloudiness': 13,
#   'Wind Speed': 2.36,
#   'Country': 'RU',
#   'Date': 1670263259},
#  {'City': 'pacific grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 287.27,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 4.02,
#   'Country': 'US',
#   'Date': 1670263065},
#  {'City': 'moyale',
#   'Lat': 3.5167,
#   'Lng': 39.0584,
#   'Max Temp': 295.08,
#   'Humidity': 54,
#   'Cloudiness': 95,
#   'Wind Speed': 2.6,
#   'Country': 'KE',
#   'Date': 1670263260},
#  {'City': 'meulaboh',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 296.65,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.35,
#   'Country': 'ID',
#   'Date': 1670263260},
#  {'City': 'puerto escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 302.62,
#   'Humidity': 47,
#   'Cloudiness': 4,
#   'Wind Speed': 2.97,
#   'Country': 'MX',
#   'Date': 1670263151},
#  {'City': 'ucluelet',
#   'Lat': 48.9329,
#   'Lng': -125.5528,
#   'Max Temp': 276.53,
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 1.7,
#   'Country': 'CA',
#   'Date': 1670263249},
#  {'City': 'heinola',
#   'Lat': 61.2056,
#   'Lng': 26.0381,
#   'Max Temp': 268.71,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.93,
#   'Country': 'FI',
#   'Date': 1670263261},
#  {'City': 'hervey bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 294.79,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'AU',
#   'Date': 1670263263},
#  {'City': 'yeppoon',
#   'Lat': -23.1333,
#   'Lng': 150.7333,
#   'Max Temp': 293.03,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 1.58,
#   'Country': 'AU',
#   'Date': 1670263264},
#  {'City': 'acajutla',
#   'Lat': 13.5928,
#   'Lng': -89.8275,
#   'Max Temp': 302.82,
#   'Humidity': 55,
#   'Cloudiness': 10,
#   'Wind Speed': 2.71,
#   'Country': 'SV',
#   'Date': 1670263264},
#  {'City': 'olinala',
#   'Lat': 17.8333,
#   'Lng': -98.85,
#   'Max Temp': 297.9,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 1.47,
#   'Country': 'MX',
#   'Date': 1670263265},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 290.42,
#   'Humidity': 69,
#   'Cloudiness': 2,
#   'Wind Speed': 3.16,
#   'Country': 'CL',
#   'Date': 1670263055},
#  {'City': 'saint-joseph',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 297.36,
#   'Humidity': 78,
#   'Cloudiness': 82,
#   'Wind Speed': 5.31,
#   'Country': 'RE',
#   'Date': 1670263212},
#  {'City': 'show low',
#   'Lat': 34.2542,
#   'Lng': -110.0298,
#   'Max Temp': 283.31,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1670263266},
#  {'City': 'chara',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': 253.28,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 2.3,
#   'Country': 'RU',
#   'Date': 1670263267},
#  {'City': 'ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 286.1,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.22,
#   'Country': 'CL',
#   'Date': 1670263267},
#  {'City': 'rusape',
#   'Lat': -18.5278,
#   'Lng': 32.1284,
#   'Max Temp': 294.33,
#   'Humidity': 39,
#   'Cloudiness': 3,
#   'Wind Speed': 2.68,
#   'Country': 'ZW',
#   'Date': 1670263268},
#  {'City': 'coquimbo',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 292.6,
#   'Humidity': 69,
#   'Cloudiness': 12,
#   'Wind Speed': 2.44,
#   'Country': 'CL',
#   'Date': 1670263269},
#  {'City': 'qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 271.61,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.48,
#   'Country': 'GL',
#   'Date': 1670263269},
#  {'City': 'sassandra',
#   'Lat': 4.95,
#   'Lng': -6.0833,
#   'Max Temp': 299.32,
#   'Humidity': 82,
#   'Cloudiness': 91,
#   'Wind Speed': 1.89,
#   'Country': 'CI',
#   'Date': 1670263270},
#  {'City': 'sechura',
#   'Lat': -5.5569,
#   'Lng': -80.8222,
#   'Max Temp': 299.06,
#   'Humidity': 53,
#   'Cloudiness': 21,
#   'Wind Speed': 4.45,
#   'Country': 'PE',
#   'Date': 1670263271},
#  {'City': 'toora-khem',
#   'Lat': 52.4675,
#   'Lng': 96.11,
#   'Max Temp': 243.22,
#   'Humidity': 99,
#   'Cloudiness': 9,
#   'Wind Speed': 0.17,
#   'Country': 'RU',
#   'Date': 1670263271},
#  {'City': 'cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 242.92,
#   'Humidity': 92,
#   'Cloudiness': 59,
#   'Wind Speed': 2.22,
#   'Country': 'RU',
#   'Date': 1670263272},
#  {'City': 'lanxi',
#   'Lat': 29.2195,
#   'Lng': 119.477,
#   'Max Temp': 279.82,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 0.79,
#   'Country': 'CN',
#   'Date': 1670263273},
#  {'City': 'jardim',
#   'Lat': -21.4803,
#   'Lng': -56.1381,
#   'Max Temp': 301.9,
#   'Humidity': 63,
#   'Cloudiness': 99,
#   'Wind Speed': 2.48,
#   'Country': 'BR',
#   'Date': 1670263274},
#  {'City': 'traralgon',
#   'Lat': -38.1833,
#   'Lng': 146.5333,
#   'Max Temp': 284.61,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.8,
#   'Country': 'AU',
#   'Date': 1670263274},
#  {'City': 'bubaque',
#   'Lat': 11.2833,
#   'Lng': -15.8333,
#   'Max Temp': 300.88,
#   'Humidity': 62,
#   'Cloudiness': 25,
#   'Wind Speed': 2.9,
#   'Country': 'GW',
#   'Date': 1670263199},
#  {'City': 'mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 286.14,
#   'Humidity': 58,
#   'Cloudiness': 62,
#   'Wind Speed': 5.4,
#   'Country': 'AU',
#   'Date': 1670263276},
#  {'City': 'svetlyy',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 272.18,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.15,
#   'Country': 'RU',
#   'Date': 1670263276},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 297.91,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 9.95,
#   'Country': 'BR',
#   'Date': 1670263277},
#  {'City': 'pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 275.15,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'CA',
#   'Date': 1670263131},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 289.36,
#   'Humidity': 89,
#   'Cloudiness': 23,
#   'Wind Speed': 0.45,
#   'Country': 'ZA',
#   'Date': 1670263062},
#  {'City': 'hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 278.37,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.08,
#   'Country': 'JP',
#   'Date': 1670263215},
#  {'City': 'aracuai',
#   'Lat': -16.8497,
#   'Lng': -42.0703,
#   'Max Temp': 299.86,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 1.09,
#   'Country': 'BR',
#   'Date': 1670263278},
#  {'City': 'atbasar',
#   'Lat': 51.8,
#   'Lng': 68.3333,
#   'Max Temp': 248.74,
#   'Humidity': 97,
#   'Cloudiness': 77,
#   'Wind Speed': 1.77,
#   'Country': 'KZ',
#   'Date': 1670262988},
#  {'City': 'marabba',
#   'Lat': 12.35,
#   'Lng': 32.1833,
#   'Max Temp': 303.3,
#   'Humidity': 25,
#   'Cloudiness': 50,
#   'Wind Speed': 4.56,
#   'Country': 'SD',
#   'Date': 1670263279},
#  {'City': 'shahr-e babak',
#   'Lat': 30.1165,
#   'Lng': 55.1186,
#   'Max Temp': 282.77,
#   'Humidity': 62,
#   'Cloudiness': 34,
#   'Wind Speed': 2.99,
#   'Country': 'IR',
#   'Date': 1670263280},
#  {'City': 'wawa',
#   'Lat': 9.9022,
#   'Lng': 4.4192,
#   'Max Temp': 303.05,
#   'Humidity': 24,
#   'Cloudiness': 51,
#   'Wind Speed': 2.23,
#   'Country': 'NG',
#   'Date': 1670263280},
#  {'City': 'laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 286.14,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1670263281},
#  {'City': 'torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 278.37,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'CA',
#   'Date': 1670263281},
#  {'City': 'udachnyy',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 250.7,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.31,
#   'Country': 'RU',
#   'Date': 1670263282},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 241.79,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Date': 1670263143},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 261,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1670263069},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 261.06,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 11.32,
#   'Country': 'SJ',
#   'Date': 1670263284},
#  {'City': 'nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 274.29,
#   'Humidity': 75,
#   'Cloudiness': 52,
#   'Wind Speed': 7.74,
#   'Country': 'GL',
#   'Date': 1670263284},
#  {'City': 'laukaa',
#   'Lat': 58.7372,
#   'Lng': 29.8453,
#   'Max Temp': 265.25,
#   'Humidity': 95,
#   'Cloudiness': 98,
#   'Wind Speed': 2.85,
#   'Country': 'RU',
#   'Date': 1670263285},
#  {'City': 'weyburn',
#   'Lat': 49.6668,
#   'Lng': -103.8511,
#   'Max Temp': 253.93,
#   'Humidity': 86,
#   'Cloudiness': 67,
#   'Wind Speed': 2.95,
#   'Country': 'CA',
#   'Date': 1670263286},
#  {'City': 'reconquista',
#   'Lat': -29.15,
#   'Lng': -59.65,
#   'Max Temp': 312.84,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 4.76,
#   'Country': 'AR',
#   'Date': 1670263287},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 276.16,
#   'Humidity': 48,
#   'Cloudiness': 40,
#   'Wind Speed': 6.17,
#   'Country': 'GL',
#   'Date': 1670263287},
#  {'City': 'devils lake',
#   'Lat': 48.1128,
#   'Lng': -98.8651,
#   'Max Temp': 259.79,
#   'Humidity': 69,
#   'Cloudiness': 95,
#   'Wind Speed': 4.92,
#   'Country': 'US',
#   'Date': 1670263176},
#  {'City': 'gorontalo',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp': 296.88,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 1.2,
#   'Country': 'ID',
#   'Date': 1670263288},
#  {'City': 'lahij',
#   'Lat': 13.1667,
#   'Lng': 44.5833,
#   'Max Temp': 294.81,
#   'Humidity': 76,
#   'Cloudiness': 31,
#   'Wind Speed': 1.78,
#   'Country': 'YE',
#   'Date': 1670263289},
#  {'City': 'saint anthony',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 272.66,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1670263290},
#  {'City': 'quatre cocos',
#   'Lat': -20.2078,
#   'Lng': 57.7625,
#   'Max Temp': 298.21,
#   'Humidity': 75,
#   'Cloudiness': 67,
#   'Wind Speed': 5.74,
#   'Country': 'MU',
#   'Date': 1670263090},
#  {'City': 'klaksvik',
#   'Lat': 62.2266,
#   'Lng': -6.589,
#   'Max Temp': 276.66,
#   'Humidity': 68,
#   'Cloudiness': 60,
#   'Wind Speed': 11.35,
#   'Country': 'FO',
#   'Date': 1670263291},
#  {'City': 'cedar lake',
#   'Lat': 41.3648,
#   'Lng': -87.4411,
#   'Max Temp': 278.63,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4.69,
#   'Country': 'US',
#   'Date': 1670263292},
#  {'City': 'vanavara',
#   'Lat': 60.34,
#   'Lng': 102.2797,
#   'Max Temp': 261.56,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 6.38,
#   'Country': 'RU',
#   'Date': 1670263293},
#  {'City': 'faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 299.47,
#   'Humidity': 77,
#   'Cloudiness': 37,
#   'Wind Speed': 7.99,
#   'Country': 'PF',
#   'Date': 1670263294},
#  {'City': 'medyn',
#   'Lat': 54.9692,
#   'Lng': 35.8586,
#   'Max Temp': 262.1,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'RU',
#   'Date': 1670263295},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 295.18,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'PE',
#   'Date': 1670263295},
#  {'City': 'chojnice',
#   'Lat': 53.6955,
#   'Lng': 17.557,
#   'Max Temp': 273.03,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'PL',
#   'Date': 1670263195},
#  {'City': 'guapiacu',
#   'Lat': -20.795,
#   'Lng': -49.2203,
#   'Max Temp': 302.69,
#   'Humidity': 48,
#   'Cloudiness': 86,
#   'Wind Speed': 5.11,
#   'Country': 'BR',
#   'Date': 1670263296},
#  {'City': 'susanville',
#   'Lat': 40.4163,
#   'Lng': -120.653,
#   'Max Temp': 275.82,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'US',
#   'Date': 1670263297},
#  {'City': 'coahuayana',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 304.56,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 2.45,
#   'Country': 'MX',
#   'Date': 1670263297},
#  {'City': 'alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 299.04,
#   'Humidity': 79,
#   'Cloudiness': 81,
#   'Wind Speed': 4.43,
#   'Country': 'NU',
#   'Date': 1670263298},
#  {'City': 'buraydah',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 292.4,
#   'Humidity': 63,
#   'Cloudiness': 97,
#   'Wind Speed': 6.74,
#   'Country': 'SA',
#   'Date': 1670263164},
#  {'City': 'mansehra',
#   'Lat': 34.3333,
#   'Lng': 73.2,
#   'Max Temp': 283.01,
#   'Humidity': 37,
#   'Cloudiness': 46,
#   'Wind Speed': 2.08,
#   'Country': 'PK',
#   'Date': 1670263299},
#  {'City': 'ponta do sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 293.71,
#   'Humidity': 73,
#   'Cloudiness': 93,
#   'Wind Speed': 2.9,
#   'Country': 'PT',
#   'Date': 1670263300},
#  {'City': 'makinsk',
#   'Lat': 52.6292,
#   'Lng': 70.4169,
#   'Max Temp': 247.44,
#   'Humidity': 100,
#   'Cloudiness': 35,
#   'Wind Speed': 1.4,
#   'Country': 'KZ',
#   'Date': 1670263301},
#  {'City': 'bambous virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 298.29,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'MU',
#   'Date': 1670263071},
#  {'City': 'bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 296.84,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.46,
#   'Country': 'ID',
#   'Date': 1670263152},
#  {'City': 'knysna',
#   'Lat': -34.0363,
#   'Lng': 23.0471,
#   'Max Temp': 288.86,
#   'Humidity': 78,
#   'Cloudiness': 34,
#   'Wind Speed': 1.91,
#   'Country': 'ZA',
#   'Date': 1670263302},
#  {'City': 'saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 289.78,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 6.91,
#   'Country': 'ZA',
#   'Date': 1670263291},
#  {'City': 'mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 298.29,
#   'Humidity': 74,
#   'Cloudiness': 85,
#   'Wind Speed': 6.07,
#   'Country': 'MU',
#   'Date': 1670263223},
#  {'City': 'san francisco',
#   'Lat': 37.7749,
#   'Lng': -122.4194,
#   'Max Temp': 287.49,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1670262780},
#  {'City': 'eureka',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 281.49,
#   'Humidity': 95,
#   'Cloudiness': 72,
#   'Wind Speed': 1.79,
#   'Country': 'US',
#   'Date': 1670263152},
#  {'City': 'port lincoln',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 287.96,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 7.35,
#   'Country': 'AU',
#   'Date': 1670263303},
#  {'City': 'bogorodskoye',
#   'Lat': 56.55,
#   'Lng': 37.8833,
#   'Max Temp': 264.29,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.02,
#   'Country': 'RU',
#   'Date': 1670263304},
#  {'City': 'nagas',
#   'Lat': 13.1059,
#   'Lng': 123.2925,
#   'Max Temp': 298.47,
#   'Humidity': 87,
#   'Cloudiness': 71,
#   'Wind Speed': 2.44,
#   'Country': 'PH',
#   'Date': 1670263304},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 296.77,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.09,
#   'Country': 'OM',
#   'Date': 1670263118},
#  {'City': 'husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 272.74,
#   'Humidity': 82,
#   'Cloudiness': 65,
#   'Wind Speed': 4.54,
#   'Country': 'IS',
#   'Date': 1670263305},
#  {'City': 'portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 277.54,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 2.68,
#   'Country': 'US',
#   'Date': 1670263150},
#  {'City': 'solvychegodsk',
#   'Lat': 61.3305,
#   'Lng': 46.9156,
#   'Max Temp': 263.45,
#   'Humidity': 69,
#   'Cloudiness': 95,
#   'Wind Speed': 3.42,
#   'Country': 'RU',
#   'Date': 1670263305},
#  {'City': 'vangaindrano',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 296.21,
#   'Humidity': 93,
#   'Cloudiness': 42,
#   'Wind Speed': 3.09,
#   'Country': 'MG',
#   'Date': 1670263306},
#  {'City': 'qostanay',
#   'Lat': 53.1667,
#   'Lng': 63.5833,
#   'Max Temp': 252.31,
#   'Humidity': 77,
#   'Cloudiness': 51,
#   'Wind Speed': 1,
#   'Country': 'KZ',
#   'Date': 1670263307},
#  {'City': 'sao joao da barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 297.86,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 8.19,
#   'Country': 'BR',
#   'Date': 1670263307},
#  {'City': 'baghdad',
#   'Lat': 33.3406,
#   'Lng': 44.4009,
#   'Max Temp': 290.23,
#   'Humidity': 42,
#   'Cloudiness': 2,
#   'Wind Speed': 2.64,
#   'Country': 'IQ',
#   'Date': 1670263308},
#  {'City': 'itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 302.74,
#   'Humidity': 60,
#   'Cloudiness': 16,
#   'Wind Speed': 8.78,
#   'Country': 'BR',
#   'Date': 1670263308},
#  {'City': 'kosh-agach',
#   'Lat': 50,
#   'Lng': 88.6667,
#   'Max Temp': 250.18,
#   'Humidity': 86,
#   'Cloudiness': 10,
#   'Wind Speed': 1.59,
#   'Country': 'RU',
#   'Date': 1670263309},
#  {'City': 'parana',
#   'Lat': -31.732,
#   'Lng': -60.5238,
#   'Max Temp': 310.68,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 4.48,
#   'Country': 'AR',
#   'Date': 1670263309},
#  {'City': 'hailun',
#   'Lat': 47.45,
#   'Lng': 126.9333,
#   'Max Temp': 253.03,
#   'Humidity': 96,
#   'Cloudiness': 6,
#   'Wind Speed': 3.73,
#   'Country': 'CN',
#   'Date': 1670263310},
#  {'City': 'nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 269.09,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 2.63,
#   'Country': 'RU',
#   'Date': 1670263310},
#  {'City': 'san quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 291.58,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 7.4,
#   'Country': 'MX',
#   'Date': 1670263311},
#  {'City': 'hanna',
#   'Lat': 51.6334,
#   'Lng': -111.9018,
#   'Max Temp': 258.63,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 2.68,
#   'Country': 'CA',
#   'Date': 1670263213},
#  {'City': 'cabo san lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 303.49,
#   'Humidity': 67,
#   'Cloudiness': 34,
#   'Wind Speed': 1.41,
#   'Country': 'MX',
#   'Date': 1670263296},
#  {'City': 'fort smith',
#   'Lat': 35.3859,
#   'Lng': -94.3986,
#   'Max Temp': 287.18,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1670263312},
#  {'City': 'novyy urengoy',
#   'Lat': 66.0833,
#   'Lng': 76.6333,
#   'Max Temp': 263.86,
#   'Humidity': 87,
#   'Cloudiness': 88,
#   'Wind Speed': 6.48,
#   'Country': 'RU',
#   'Date': 1670263313},
#  {'City': 'iquique',
#   'Lat': -20.2208,
#   'Lng': -70.1431,
#   'Max Temp': 294.87,
#   'Humidity': 62,
#   'Cloudiness': 41,
#   'Wind Speed': 3.32,
#   'Country': 'CL',
#   'Date': 1670263313},
#  {'City': 'qasigiannguit',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 276.29,
#   'Humidity': 78,
#   'Cloudiness': 47,
#   'Wind Speed': 3.61,
#   'Country': 'GL',
#   'Date': 1670263313},
#  {'City': 'deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 242.46,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.78,
#   'Country': 'RU',
#   'Date': 1670263314},
#  {'City': 'kandiari',
#   'Lat': 26.9156,
#   'Lng': 68.5216,
#   'Max Temp': 292.63,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 1.15,
#   'Country': 'PK',
#   'Date': 1670263314},
#  {'City': 'taoudenni',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 302.85,
#   'Humidity': 14,
#   'Cloudiness': 25,
#   'Wind Speed': 1.14,
#   'Country': 'ML',
#   'Date': 1670263315},
#  {'City': 'aswan',
#   'Lat': 24.0934,
#   'Lng': 32.907,
#   'Max Temp': 292.85,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 5.26,
#   'Country': 'EG',
#   'Date': 1670263316},
#  {'City': 'shibetsu',
#   'Lat': 43.659,
#   'Lng': 145.132,
#   'Max Temp': 269.04,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 1.76,
#   'Country': 'JP',
#   'Date': 1670263300},
#  {'City': 'kenai',
#   'Lat': 60.5544,
#   'Lng': -151.2583,
#   'Max Temp': 269.9,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1670263071},
#  {'City': 'monte escobedo',
#   'Lat': 22.3,
#   'Lng': -103.5833,
#   'Max Temp': 293.42,
#   'Humidity': 29,
#   'Cloudiness': 7,
#   'Wind Speed': 1.76,
#   'Country': 'MX',
#   'Date': 1670263317},
#  {'City': 'port hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 301.18,
#   'Humidity': 61,
#   'Cloudiness': 10,
#   'Wind Speed': 6.17,
#   'Country': 'AU',
#   'Date': 1670263317},
#  {'City': 'kloulklubed',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 300.95,
#   'Humidity': 75,
#   'Cloudiness': 88,
#   'Wind Speed': 4.86,
#   'Country': 'PW',
#   'Date': 1670263318},
#  {'City': 'constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 293.5,
#   'Humidity': 56,
#   'Cloudiness': 5,
#   'Wind Speed': 7.23,
#   'Country': 'CL',
#   'Date': 1670263051},
#  {'City': 'muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 285.45,
#   'Humidity': 83,
#   'Cloudiness': 89,
#   'Wind Speed': 2.27,
#   'Country': 'ES',
#   'Date': 1670263318},
#  {'City': 'srandakan',
#   'Lat': -7.9386,
#   'Lng': 110.2506,
#   'Max Temp': 298.48,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 0.58,
#   'Country': 'ID',
#   'Date': 1670263319},
#  {'City': 'kambove',
#   'Lat': -10.8764,
#   'Lng': 26.5969,
#   'Max Temp': 289.49,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 1.25,
#   'Country': 'CD',
#   'Date': 1670263319},
#  {'City': 'sidi ali',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 291.2,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind Speed': 3.21,
#   'Country': 'DZ',
#   'Date': 1670263320},
#  {'City': 'san vicente de canete',
#   'Lat': -13.0751,
#   'Lng': -76.3835,
#   'Max Temp': 294.99,
#   'Humidity': 71,
#   'Cloudiness': 18,
#   'Wind Speed': 3.87,
#   'Country': 'PE',
#   'Date': 1670263320},
#  {'City': 'hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 282.54,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': 1670263203},
#  {'City': 'dedovichi',
#   'Lat': 57.5517,
#   'Lng': 29.9502,
#   'Max Temp': 264.25,
#   'Humidity': 93,
#   'Cloudiness': 98,
#   'Wind Speed': 3.77,
#   'Country': 'RU',
#   'Date': 1670263321},
#  {'City': 'cravo norte',
#   'Lat': 6.3017,
#   'Lng': -70.2041,
#   'Max Temp': 304.63,
#   'Humidity': 51,
#   'Cloudiness': 22,
#   'Wind Speed': 3.55,
#   'Country': 'CO',
#   'Date': 1670263322},
#  {'City': 'lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 299.19,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Country': 'PG',
#   'Date': 1670263323},
#  {'City': 'cap malheureux',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 298.41,
#   'Humidity': 68,
#   'Cloudiness': 57,
#   'Wind Speed': 2.24,
#   'Country': 'MU',
#   'Date': 1670263323},
#  {'City': 'axim',
#   'Lat': 4.8699,
#   'Lng': -2.2405,
#   'Max Temp': 300.11,
#   'Humidity': 80,
#   'Cloudiness': 45,
#   'Wind Speed': 3.76,
#   'Country': 'GH',
#   'Date': 1670263324},
#  {'City': 'ndjole',
#   'Lat': -0.1783,
#   'Lng': 10.7649,
#   'Max Temp': 298.72,
#   'Humidity': 90,
#   'Cloudiness': 70,
#   'Wind Speed': 1.17,
#   'Country': 'GA',
#   'Date': 1670263325},
#  {'City': 'sungurlu',
#   'Lat': 40.1675,
#   'Lng': 34.3739,
#   'Max Temp': 279.7,
#   'Humidity': 63,
#   'Cloudiness': 89,
#   'Wind Speed': 1.57,
#   'Country': 'TR',
#   'Date': 1670263325},
#  {'City': 'vesyegonsk',
#   'Lat': 58.664,
#   'Lng': 37.2604,
#   'Max Temp': 264.79,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.87,
#   'Country': 'RU',
#   'Date': 1670263326},
#  {'City': 'macusani',
#   'Lat': -14.0833,
#   'Lng': -70.4333,
#   'Max Temp': 281.3,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 5.66,
#   'Country': 'PE',
#   'Date': 1670263327},
#  {'City': 'erdenet',
#   'Lat': 49.0333,
#   'Lng': 104.0833,
#   'Max Temp': 249.94,
#   'Humidity': 86,
#   'Cloudiness': 4,
#   'Wind Speed': 2.14,
#   'Country': 'MN',
#   'Date': 1670263328},
#  {'City': 'knyaze-volkonskoye',
#   'Lat': 48.4642,
#   'Lng': 135.4567,
#   'Max Temp': 258.34,
#   'Humidity': 87,
#   'Cloudiness': 15,
#   'Wind Speed': 5.5,
#   'Country': 'RU',
#   'Date': 1670263328},
#  {'City': 'chateauroux',
#   'Lat': 46.8167,
#   'Lng': 1.7,
#   'Max Temp': 278.15,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'FR',
#   'Date': 1670263166},
#  {'City': 'belmonte',
#   'Lat': -15.8631,
#   'Lng': -38.8828,
#   'Max Temp': 298.92,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 3.52,
#   'Country': 'BR',
#   'Date': 1670263329},
#  {'City': 'tripoli',
#   'Lat': 32.8752,
#   'Lng': 13.1875,
#   'Max Temp': 293.3,
#   'Humidity': 64,
#   'Cloudiness': 46,
#   'Wind Speed': 2.01,
#   'Country': 'LY',
#   'Date': 1670263164},
#  {'City': 'ivdel',
#   'Lat': 60.6911,
#   'Lng': 60.4206,
#   'Max Temp': 254.56,
#   'Humidity': 99,
#   'Cloudiness': 95,
#   'Wind Speed': 0.91,
#   'Country': 'RU',
#   'Date': 1670263330},
#  {'City': 'yurla',
#   'Lat': 59.3259,
#   'Lng': 54.3223,
#   'Max Temp': 257.84,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 1.1,
#   'Country': 'RU',
#   'Date': 1670263331},
#  {'City': 'totolapan',
#   'Lat': 18.5167,
#   'Lng': -96.1833,
#   'Max Temp': 300.28,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 0.34,
#   'Country': 'MX',
#   'Date': 1670263331},
#  {'City': 'general roca',
#   'Lat': -39.0333,
#   'Lng': -67.5833,
#   'Max Temp': 306.83,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 7.63,
#   'Country': 'AR',
#   'Date': 1670263332},
#  {'City': 'smithers',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 254.33,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Country': 'CA',
#   'Date': 1670263187},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 276.97,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'US',
#   'Date': 1670263068},
#  {'City': 'leningradskiy',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': 248.8,
#   'Humidity': 89,
#   'Cloudiness': 55,
#   'Wind Speed': 3.06,
#   'Country': 'RU',
#   'Date': 1670263175},
#  {'City': 'poitiers',
#   'Lat': 46.5833,
#   'Lng': 0.3333,
#   'Max Temp': 277.18,
#   'Humidity': 63,
#   'Cloudiness': 27,
#   'Wind Speed': 2.06,
#   'Country': 'FR',
#   'Date': 1670263148},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 299.3,
#   'Humidity': 61,
#   'Cloudiness': 79,
#   'Wind Speed': 6.72,
#   'Country': 'US',
#   'Date': 1670263334},
#  {'City': 'oksfjord',
#   'Lat': 70.2396,
#   'Lng': 22.3479,
#   'Max Temp': 276.25,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'NO',
#   'Date': 1670263335},
#  {'City': 'newport',
#   'Lat': 51.5877,
#   'Lng': -2.9984,
#   'Max Temp': 280.72,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 7.65,
#   'Country': 'GB',
#   'Date': 1670263335},
#  {'City': 'warwick',
#   'Lat': 41.7001,
#   'Lng': -71.4162,
#   'Max Temp': 283.2,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1670263336},
#  {'City': 'polis',
#   'Lat': 35.0367,
#   'Lng': 32.4264,
#   'Max Temp': 289.05,
#   'Humidity': 73,
#   'Cloudiness': 8,
#   'Wind Speed': 0.92,
#   'Country': 'CY',
#   'Date': 1670263337},
#  {'City': 'rostovka',
#   'Lat': 55.3842,
#   'Lng': 71.8891,
#   'Max Temp': 250.07,
#   'Humidity': 99,
#   'Cloudiness': 24,
#   'Wind Speed': 0.88,
#   'Country': 'RU',
#   'Date': 1670263337},
#  {'City': 'mareeba',
#   'Lat': -17,
#   'Lng': 145.4333,
#   'Max Temp': 292.55,
#   'Humidity': 91,
#   'Cloudiness': 2,
#   'Wind Speed': 0.78,
# ...
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 2.32,
#   'Country': 'GE',
#   'Date': 1670263445},
#  {'City': 'clyde river',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 261.28,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'CA',
#   'Date': 1670263446},
#  {'City': 'sala consilina',
#   'Lat': 40.3912,
#   'Lng': 15.5989,
#   'Max Temp': 283.36,
#   'Humidity': 86,
#   'Cloudiness': 85,
#   'Wind Speed': 1.03,
#   'Country': 'IT',
#   'Date': 1670263447},
#  {'City': 'itacoatiara',
#   'Lat': -3.1431,
#   'Lng': -58.4442,
#   'Max Temp': 302.81,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'BR',
#   'Date': 1670263447},
#  {'City': 'kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 299.68,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 1.94,
#   'Country': 'PG',
#   'Date': 1670263448},
#  {'City': 'praxedis guerrero',
#   'Lat': 31.3667,
#   'Lng': -106.0167,
#   'Max Temp': 290.85,
#   'Humidity': 44,
#   'Cloudiness': 42,
#   'Wind Speed': 3.15,
#   'Country': 'MX',
#   'Date': 1670263449},
#  {'City': 'carutapera',
#   'Lat': -1.195,
#   'Lng': -46.02,
#   'Max Temp': 302.75,
#   'Humidity': 60,
#   'Cloudiness': 74,
#   'Wind Speed': 5.27,
#   'Country': 'BR',
#   'Date': 1670263449},
#  {'City': 'mecca',
#   'Lat': 21.4267,
#   'Lng': 39.8261,
#   'Max Temp': 298.52,
#   'Humidity': 66,
#   'Cloudiness': 23,
#   'Wind Speed': 2.21,
#   'Country': 'SA',
#   'Date': 1670263350},
#  {'City': 'waingapu',
#   'Lat': -9.6567,
#   'Lng': 120.2641,
#   'Max Temp': 299.05,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Country': 'ID',
#   'Date': 1670263450},
#  {'City': 'strezhevoy',
#   'Lat': 60.7333,
#   'Lng': 77.5889,
#   'Max Temp': 257.92,
#   'Humidity': 96,
#   'Cloudiness': 94,
#   'Wind Speed': 3.6,
#   'Country': 'RU',
#   'Date': 1670263450},
#  {'City': 'yaransk',
#   'Lat': 57.3033,
#   'Lng': 47.8861,
#   'Max Temp': 252.48,
#   'Humidity': 99,
#   'Cloudiness': 66,
#   'Wind Speed': 2.16,
#   'Country': 'RU',
#   'Date': 1670263451},
#  {'City': 'komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 272.55,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'UZ',
#   'Date': 1670263451},
#  {'City': 'promyshlennaya',
#   'Lat': 54.9159,
#   'Lng': 85.6385,
#   'Max Temp': 249.68,
#   'Humidity': 99,
#   'Cloudiness': 30,
#   'Wind Speed': 0.61,
#   'Country': 'RU',
#   'Date': 1670263452},
#  {'City': 'moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 310.38,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 4.23,
#   'Country': 'AR',
#   'Date': 1670263453},
#  {'City': 'lena',
#   'Lat': 43.1,
#   'Lng': -5.7333,
#   'Max Temp': 277.69,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 2.08,
#   'Country': 'ES',
#   'Date': 1670263453},
#  {'City': 'watsa',
#   'Lat': 3.0372,
#   'Lng': 29.5355,
#   'Max Temp': 292.25,
#   'Humidity': 91,
#   'Cloudiness': 97,
#   'Wind Speed': 1.45,
#   'Country': 'CD',
#   'Date': 1670263159},
#  {'City': 'beloha',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 298.47,
#   'Humidity': 77,
#   'Cloudiness': 35,
#   'Wind Speed': 4.32,
#   'Country': 'MG',
#   'Date': 1670263454},
#  {'City': 'san carlos del zulia',
#   'Lat': 9,
#   'Lng': -71.9135,
#   'Max Temp': 301.25,
#   'Humidity': 69,
#   'Cloudiness': 51,
#   'Wind Speed': 0.75,
#   'Country': 'VE',
#   'Date': 1670263454},
#  {'City': 'coatesville',
#   'Lat': 39.9832,
#   'Lng': -75.8238,
#   'Max Temp': 281.84,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1670263354},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 261.75,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 3.81,
#   'Country': 'RU',
#   'Date': 1670263455},
#  {'City': 'tucurui',
#   'Lat': -3.7661,
#   'Lng': -49.6725,
#   'Max Temp': 300.87,
#   'Humidity': 67,
#   'Cloudiness': 85,
#   'Wind Speed': 2.67,
#   'Country': 'BR',
#   'Date': 1670263456},
#  {'City': 'prachuap khiri khan',
#   'Lat': 12.2167,
#   'Lng': 99.75,
#   'Max Temp': 294.39,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.31,
#   'Country': 'TH',
#   'Date': 1670263261},
#  {'City': 'polunochnoye',
#   'Lat': 60.8697,
#   'Lng': 60.4153,
#   'Max Temp': 254.11,
#   'Humidity': 100,
#   'Cloudiness': 96,
#   'Wind Speed': 1.09,
#   'Country': 'RU',
#   'Date': 1670263456},
#  {'City': 'sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 296.94,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 0.84,
#   'Country': 'ID',
#   'Date': 1670263457},
#  {'City': 'palanga',
#   'Lat': 55.9175,
#   'Lng': 21.0686,
#   'Max Temp': 271.16,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'LT',
#   'Date': 1670263457},
#  {'City': 'sapele',
#   'Lat': 5.8941,
#   'Lng': 5.6767,
#   'Max Temp': 301.59,
#   'Humidity': 71,
#   'Cloudiness': 35,
#   'Wind Speed': 3.41,
#   'Country': 'NG',
#   'Date': 1670263458},
#  {'City': 'hilter',
#   'Lat': 52.15,
#   'Lng': 8.15,
#   'Max Temp': 274,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.06,
#   'Country': 'DE',
#   'Date': 1670263459},
#  {'City': 'mahajanga',
#   'Lat': -15.7167,
#   'Lng': 46.3167,
#   'Max Temp': 300.16,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'MG',
#   'Date': 1670263459},
#  {'City': 'albion',
#   'Lat': 42.2431,
#   'Lng': -84.753,
#   'Max Temp': 278.6,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1670263460},
#  {'City': 'grand gaube',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 298.37,
#   'Humidity': 68,
#   'Cloudiness': 55,
#   'Wind Speed': 3.13,
#   'Country': 'MU',
#   'Date': 1670263460},
#  {'City': 'boca do acre',
#   'Lat': -8.7522,
#   'Lng': -67.3978,
#   'Max Temp': 309.25,
#   'Humidity': 35,
#   'Cloudiness': 76,
#   'Wind Speed': 0.63,
#   'Country': 'BR',
#   'Date': 1670263461},
#  {'City': 'kaka',
#   'Lat': 37.3482,
#   'Lng': 59.6143,
#   'Max Temp': 272.6,
#   'Humidity': 52,
#   'Cloudiness': 13,
#   'Wind Speed': 2.29,
#   'Country': 'TM',
#   'Date': 1670263462},
#  {'City': 'shetpe',
#   'Lat': 44.1667,
#   'Lng': 52.1167,
#   'Max Temp': 266.73,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 0.32,
#   'Country': 'KZ',
#   'Date': 1670263462},
#  {'City': 'tambacounda',
#   'Lat': 13.7539,
#   'Lng': -13.7586,
#   'Max Temp': 305.9,
#   'Humidity': 18,
#   'Cloudiness': 7,
#   'Wind Speed': 1.63,
#   'Country': 'SN',
#   'Date': 1670263462},
#  {'City': 'teguise',
#   'Lat': 29.0605,
#   'Lng': -13.564,
#   'Max Temp': 294.27,
#   'Humidity': 64,
#   'Cloudiness': 20,
#   'Wind Speed': 3.6,
#   'Country': 'ES',
#   'Date': 1670263463},
#  {'City': 'yueyang',
#   'Lat': 29.3333,
#   'Lng': 113.0919,
#   'Max Temp': 279.1,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 0.71,
#   'Country': 'CN',
#   'Date': 1670263223},
#  {'City': 'zapolyarnyy',
#   'Lat': 69.4154,
#   'Lng': 30.8136,
#   'Max Temp': 266.75,
#   'Humidity': 93,
#   'Cloudiness': 86,
#   'Wind Speed': 5.7,
#   'Country': 'RU',
#   'Date': 1670263464},
#  {'City': 'bijie',
#   'Lat': 27.3125,
#   'Lng': 105.2942,
#   'Max Temp': 275.62,
#   'Humidity': 85,
#   'Cloudiness': 48,
#   'Wind Speed': 2.02,
#   'Country': 'CN',
#   'Date': 1670263464},
#  {'City': 'yokadouma',
#   'Lat': 3.5167,
#   'Lng': 15.05,
#   'Max Temp': 298.38,
#   'Humidity': 62,
#   'Cloudiness': 44,
#   'Wind Speed': 0.64,
#   'Country': 'CM',
#   'Date': 1670263465},
#  {'City': 'bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': 248.66,
#   'Humidity': 67,
#   'Cloudiness': 81,
#   'Wind Speed': 2.57,
#   'Country': 'RU',
#   'Date': 1670263466},
#  {'City': 'port blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 300.19,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.16,
#   'Country': 'IN',
#   'Date': 1670263466},
#  {'City': 'lydenburg',
#   'Lat': -25.0978,
#   'Lng': 30.4597,
#   'Max Temp': 288.78,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Country': 'ZA',
#   'Date': 1670263466},
#  {'City': 'waitara',
#   'Lat': -38.925,
#   'Lng': 174.25,
#   'Max Temp': 287.72,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.35,
#   'Country': 'NZ',
#   'Date': 1670263467},
#  {'City': 'ha tinh',
#   'Lat': 18.3333,
#   'Lng': 105.9,
#   'Max Temp': 289.19,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.92,
#   'Country': 'VN',
#   'Date': 1670263468},
#  {'City': 'loandjili',
#   'Lat': -4.7561,
#   'Lng': 11.8578,
#   'Max Temp': 298.44,
#   'Humidity': 88,
#   'Cloudiness': 92,
#   'Wind Speed': 3.37,
#   'Country': 'CG',
#   'Date': 1670263468},
#  {'City': 'dubai',
#   'Lat': 25.2582,
#   'Lng': 55.3047,
#   'Max Temp': 298.14,
#   'Humidity': 68,
#   'Cloudiness': 14,
#   'Wind Speed': 1.55,
#   'Country': 'AE',
#   'Date': 1670263410},
#  {'City': 'turinsk',
#   'Lat': 58.0458,
#   'Lng': 63.696,
#   'Max Temp': 253.08,
#   'Humidity': 100,
#   'Cloudiness': 64,
#   'Wind Speed': 1.24,
#   'Country': 'RU',
#   'Date': 1670263469},
#  {'City': 'ygatimi',
#   'Lat': -24.0833,
#   'Lng': -55.5,
#   'Max Temp': 308.11,
#   'Humidity': 36,
#   'Cloudiness': 43,
#   'Wind Speed': 1.38,
#   'Country': 'PY',
#   'Date': 1670263470},
#  {'City': 'vredendal',
#   'Lat': -31.6683,
#   'Lng': 18.5012,
#   'Max Temp': 290.07,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 6.26,
#   'Country': 'ZA',
#   'Date': 1670263470},
#  {'City': 'abu samrah',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 286.55,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 2.56,
#   'Country': 'SY',
#   'Date': 1670263471},
#  {'City': 'ust-kuyga',
#   'Lat': 70.0167,
#   'Lng': 135.6,
#   'Max Temp': 243.73,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'RU',
#   'Date': 1670263472},
#  {'City': 'novomykolayivka',
#   'Lat': 47.9781,
#   'Lng': 35.9102,
#   'Max Temp': 268.54,
#   'Humidity': 47,
#   'Cloudiness': 6,
#   'Wind Speed': 6.2,
#   'Country': 'UA',
#   'Date': 1670263237},
#  {'City': 'sakakah',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 288.02,
#   'Humidity': 60,
#   'Cloudiness': 4,
#   'Wind Speed': 3.91,
#   'Country': 'SA',
#   'Date': 1670263472},
#  {'City': 'dauphin',
#   'Lat': 51.1494,
#   'Lng': -100.0502,
#   'Max Temp': 251.44,
#   'Humidity': 83,
#   'Cloudiness': 55,
#   'Wind Speed': 2.99,
#   'Country': 'CA',
#   'Date': 1670263473},
#  {'City': 'maraba',
#   'Lat': -5.3686,
#   'Lng': -49.1178,
#   'Max Temp': 301.25,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 0.51,
#   'Country': 'BR',
#   'Date': 1670263473},
#  {'City': 'mokhsogollokh',
#   'Lat': 61.4681,
#   'Lng': 128.9203,
#   'Max Temp': 245.72,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.05,
#   'Country': 'RU',
#   'Date': 1670263474},
#  {'City': 'dudinka',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': 269,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.06,
#   'Country': 'RU',
#   'Date': 1670263474},
#  {'City': 'ciudad bolivar',
#   'Lat': 8.1222,
#   'Lng': -63.5497,
#   'Max Temp': 303.25,
#   'Humidity': 51,
#   'Cloudiness': 96,
#   'Wind Speed': 2.12,
#   'Country': 'VE',
#   'Date': 1670263475},
#  {'City': 'launceston',
#   'Lat': -41.45,
#   'Lng': 147.1667,
#   'Max Temp': 282.93,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.17,
#   'Country': 'AU',
#   'Date': 1670263475},
#  {'City': 'chinsali',
#   'Lat': -10.5414,
#   'Lng': 32.0816,
#   'Max Temp': 295.29,
#   'Humidity': 56,
#   'Cloudiness': 97,
#   'Wind Speed': 1.24,
#   'Country': 'ZM',
#   'Date': 1670263476},
#  {'City': 'torbat-e jam',
#   'Lat': 35.244,
#   'Lng': 60.6225,
#   'Max Temp': 272,
#   'Humidity': 70,
#   'Cloudiness': 91,
#   'Wind Speed': 0.5,
#   'Country': 'IR',
#   'Date': 1670263477},
#  {'City': 'zenzeli',
#   'Lat': 45.9241,
#   'Lng': 47.0474,
#   'Max Temp': 266.95,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 3.01,
#   'Country': 'RU',
#   'Date': 1670263477},
#  {'City': 'naze',
#   'Lat': 28.3667,
#   'Lng': 129.4833,
#   'Max Temp': 289.08,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 8.77,
#   'Country': 'JP',
#   'Date': 1670263478},
#  {'City': 'vitim',
#   'Lat': 59.4511,
#   'Lng': 112.5578,
#   'Max Temp': 260.18,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 6.1,
#   'Country': 'RU',
#   'Date': 1670263478},
#  {'City': 'mahina',
#   'Lat': -17.5065,
#   'Lng': -149.489,
#   'Max Temp': 300.02,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 2.06,
#   'Country': 'PF',
#   'Date': 1670263205},
#  {'City': 'ouegoa',
#   'Lat': -20.35,
#   'Lng': 164.4333,
#   'Max Temp': 299.11,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.55,
#   'Country': 'NC',
#   'Date': 1670263479},
#  {'City': 'labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 299.8,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'ID',
#   'Date': 1670263250},
#  {'City': 'salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 297.45,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 0.41,
#   'Country': 'OM',
#   'Date': 1670263190},
#  {'City': 'altay',
#   'Lat': 47.8667,
#   'Lng': 88.1167,
#   'Max Temp': 260.76,
#   'Humidity': 83,
#   'Cloudiness': 78,
#   'Wind Speed': 2.27,
#   'Country': 'CN',
#   'Date': 1670263480},
#  {'City': 'san jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 287.16,
#   'Humidity': 90,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1670263202},
#  {'City': 'san',
#   'Lat': 13.3034,
#   'Lng': -4.8956,
#   'Max Temp': 304.71,
#   'Humidity': 18,
#   'Cloudiness': 98,
#   'Wind Speed': 3.31,
#   'Country': 'ML',
#   'Date': 1670263480},
#  {'City': 'majene',
#   'Lat': -3.5403,
#   'Lng': 118.9707,
#   'Max Temp': 298.18,
#   'Humidity': 87,
#   'Cloudiness': 99,
#   'Wind Speed': 1.5,
#   'Country': 'ID',
#   'Date': 1670263481},
#  {'City': 'bahia blanca',
#   'Lat': -38.7196,
#   'Lng': -62.2724,
#   'Max Temp': 307.75,
#   'Humidity': 25,
#   'Cloudiness': 23,
#   'Wind Speed': 0.89,
#   'Country': 'AR',
#   'Date': 1670263422},
#  {'City': 'ust-omchug',
#   'Lat': 61.15,
#   'Lng': 149.6333,
#   'Max Temp': 230.9,
#   'Humidity': 100,
#   'Cloudiness': 73,
#   'Wind Speed': 0.63,
#   'Country': 'RU',
#   'Date': 1670263481},
#  {'City': 'half moon bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 287.52,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1670263482},
#  {'City': 'taksimo',
#   'Lat': 56.3444,
#   'Lng': 114.8794,
#   'Max Temp': 256.81,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.65,
#   'Country': 'RU',
#   'Date': 1670263482},
#  {'City': 'nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 272.19,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1670263483},
#  {'City': 'port arthur',
#   'Lat': 38.8,
#   'Lng': 121.2667,
#   'Max Temp': 274.27,
#   'Humidity': 40,
#   'Cloudiness': 2,
#   'Wind Speed': 9.14,
#   'Country': 'CN',
#   'Date': 1670263466},
#  {'City': 'novoagansk',
#   'Lat': 61.9449,
#   'Lng': 76.6625,
#   'Max Temp': 262.59,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'RU',
#   'Date': 1670263483},
#  {'City': 'alamogordo',
#   'Lat': 32.8995,
#   'Lng': -105.9603,
#   'Max Temp': 294.48,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1670263484},
#  {'City': 'virginia beach',
#   'Lat': 36.8529,
#   'Lng': -75.978,
#   'Max Temp': 286.17,
#   'Humidity': 62,
#   'Cloudiness': 74,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': 1670263484},
#  {'City': 'ishigaki',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 294.9,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 14.82,
#   'Country': 'JP',
#   'Date': 1670263213},
#  {'City': 'samsun',
#   'Lat': 41.25,
#   'Lng': 36.3333,
#   'Max Temp': 285.92,
#   'Humidity': 97,
#   'Cloudiness': 85,
#   'Wind Speed': 1.68,
#   'Country': 'TR',
#   'Date': 1670263251},
#  {'City': 'praia da vitoria',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 289.13,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.53,
#   'Country': 'PT',
#   'Date': 1670263485},
#  {'City': 'kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 298.06,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 3.58,
#   'Country': 'US',
#   'Date': 1670263486},
#  {'City': 'nazareno',
#   'Lat': 25.3833,
#   'Lng': -103.4167,
#   'Max Temp': 297.32,
#   'Humidity': 29,
#   'Cloudiness': 51,
#   'Wind Speed': 0.56,
#   'Country': 'MX',
#   'Date': 1670263486},
#  {'City': 'zeya',
#   'Lat': 53.75,
#   'Lng': 127.2667,
#   'Max Temp': 250.46,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.4,
#   'Country': 'RU',
#   'Date': 1670263487},
#  {'City': 'birin',
#   'Lat': 26.8865,
#   'Lng': 88.0718,
#   'Max Temp': 282.59,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 2.14,
#   'Country': 'NP',
#   'Date': 1670263488}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  bredasdorp -34.5322   20.0403    289.40        62          50        2.58
# 1   ostrovnoy  68.0531   39.5131    265.90        91          98        8.57
# 2     talnakh  69.4865   88.3972    269.38        96         100        6.32
# 3  codrington -38.2667  141.9667    283.46        76          15        4.67
# 4     ushuaia -54.8000  -68.3000    284.94        46          40       11.83
#
#   Country        Date
# 0      ZA  1670263188
# 1      RU  1670263189
# 2      RU  1670263189
# 3      AU  1670263065
# 4      AR  1670263066

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        bredasdorp -34.5322   20.0403    289.40        62          50
# 1         ostrovnoy  68.0531   39.5131    265.90        91          98
# 2           talnakh  69.4865   88.3972    269.38        96         100
# 3        codrington -38.2667  141.9667    283.46        76          15
# 4           ushuaia -54.8000  -68.3000    284.94        46          40
#
#          Wind Speed Country        Date
# City_ID
# 0              2.58      ZA  1670263188
# 1              8.57      RU  1670263189
# 2              6.32      RU  1670263189
# 3              4.67      AU  1670263065
# 4             11.83      AR  1670263066

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x = city_data_df['Lat']
y=city_data_df['Max Temp']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Temperature in F')
plt.title('Max Temp vs. Latitude')
plt.grid(axis = 'both')
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x = city_data_df['Lat']
y=city_data_df['Humidity']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.title('Humidity vs. City Latitude')
plt.grid(axis = 'both')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x = city_data_df['Lat']
y=city_data_df['Cloudiness']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.title('Cloudiness vs. City Latitude')
plt.grid(axis = 'both')


# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x = city_data_df['Lat']
y=city_data_df['Wind Speed']
plt.scatter(x,y, marker="o", facecolors='blue',alpha=0.75)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Wind Speed vs. City Latitude')
plt.grid(axis = 'both')
# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def func_regression(x,y,df,n):
    headers = list(df.columns)
    x = df[headers[1]]
    y=df[headers[n]]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y)
    plt.plot(x,regress_values,"r-")
    correlation = st.pearsonr(x,y)
    print(f"The correlation between {headers[n]} and Latitude is {round(correlation[0],2)}")
    plt.xlabel('Latitude')
    plt.ylabel(headers[n])
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=city_data_df[city_data_df[('Lat')]>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           ostrovnoy  68.0531   39.5131    265.90        91          98
# 2             talnakh  69.4865   88.3972    269.38        96         100
# 5        saint george  37.1041 -113.5841    283.39        69         100
# 6             kouqian  43.6391  126.4578    261.16        74           1
# 8            khatanga  71.9667  102.5000    241.13       100          28
#
#          Wind Speed Country        Date
# City_ID
# 1              8.57      RU  1670263189
# 2              6.32      RU  1670263189
# 5              0.00      US  1670262895
# 6              3.66      CN  1670263190
# 8              1.52      RU  1670263191

# %%
list(northern_hemi_df.columns)
# Out:
# ['City',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Country',
#  'Date']

# %%
# northern_hemi_df.rename(columns = {'Lat':'Latitude','Lng':'Longitude','Max Temp' : 'Temperature'}, inplace = True)
# northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=city_data_df[city_data_df[('Lat')]<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        bredasdorp -34.5322   20.0403    289.40        62          50
# 3        codrington -38.2667  141.9667    283.46        76          15
# 4           ushuaia -54.8000  -68.3000    284.94        46          40
# 7         busselton -33.6500  115.3333    286.06        89          51
# 12         luderitz -26.6481   15.1594    290.55        63           1
#
#          Wind Speed Country        Date
# City_ID
# 0              2.58      ZA  1670263188
# 3              4.67      AU  1670263065
# 4             11.83      AR  1670263066
# 7              5.39      AU  1670262999
# 12            11.60     NaN  1670263192

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# x = northern_hemi_df['Lat']
# y = northern_hemi_df['Max Temp']
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
# regress_values = x * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(x,y)
# plt.plot(x,regress_values,"r-")
# correlation = st.pearsonr(x,y)
# print(f"The correlation between Temperature and Latitude is {round(correlation[0],2)}")
# plt.xlabel('Latitude')
# plt.ylabel('Temperature')
# plt.annotate(line_eq,xy=(-50,intercept))
# plt.show()

# %%
func_regression(x,y,northern_hemi_df,3)
# Out:
# The correlation between Max Temp and Latitude is -0.84

# %%
# Linear regression on Southern Hemisphere
func_regression(x,y,southern_hemi_df,3)
# Out:
# The correlation between Max Temp and Latitude is 0.48

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
x1 = northern_hemi_df['Lat']
y1 = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x1, y1)
regress_values = x1 * slope + intercept
line_eq = "y1 = " + str(round(slope,2)) + "x1 + " + str(round(intercept,2))
plt.scatter(x1,y1)
plt.plot(x1,regress_values,"r-")
correlation = st.pearsonr(x1,y1)
print(f"The r value or the correlation is {round(rvalue,2)}")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,xy=(60,50))
plt.show()
# Out:
# The r value or the correlation is 0.43

# %%
# Northern Hemisphere
func_regression(x,y,northern_hemi_df,4)
# Out:
# The correlation between Humidity and Latitude is 0.43

# %%
# Southern Hemisphere
func_regression(x,y,southern_hemi_df,4)
# Out:
# The correlation between Humidity and Latitude is 0.16

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
func_regression(x,y,northern_hemi_df,5)
# Out:
# The correlation between Cloudiness and Latitude is 0.23

# %%
# Southern Hemisphere
func_regression(x,y,southern_hemi_df,5)
# Out:
# The correlation between Cloudiness and Latitude is 0.19

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
func_regression(x,y,northern_hemi_df,6)
# Out:
# The correlation between Wind Speed and Latitude is 0.23

# %%
# Southern Hemisphere
func_regression(x,y,southern_hemi_df,6)
# Out:
# The correlation between Wind Speed and Latitude is -0.28

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
